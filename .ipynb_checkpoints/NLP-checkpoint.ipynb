# %% [markdown]
# # Machine Translation

# %%
import re
import os
import numpy as np
import jieba
import collections

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split

# %%
# Verify  GPU
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2364601044088442577
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15862523495
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#   }
# }
# incarnation: 11462742767717835920
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:87:00.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preparation
# ### 1.1 Load Data

# %%
# Load English data
print("Loading data...")

def load_data(path):
    """
    Load dataset
    """
    input_file = os.path.join(path)
    with open(input_file, "r") as f:
        data = f.read()

    return data.split('\n')

en_sentences = load_data('data/train.txt.en')

# Load Chinese data
cn_sentences = load_data('data/train.txt.zh')
# Out:
# Loading data...

# %%
print('Dataset Loaded')
print("lenght of Source sentences:", len(en_sentences))
print("Source sample: ", en_sentences[0])

print("lenght of Target sentences:", len(en_sentences))
print("Target sample: ", cn_sentences[0].replace(" ",""))
# Out:
# Dataset Loaded
# lenght of Source sentences: 209941
# Source sample:  This is Bill Lange . I 'm Dave Gallo .
# lenght of Target sentences: 209941
# Target sample:  大卫.盖罗：这位是比尔.兰格，我是大卫.盖罗。

# %% [markdown]
# ### 1.2 Filter out sentences with length more than 50

# %%
en_list = []
cn_list = []

#===========input parameter ========================
max_len = 50
#max_vocab_size = 50000
en_vocab_size = 50000 
cn_vocab_size = 10000
max_rows = 200000
#===================================================

def clean_eng(x):
    x = x.lower()
    x = re.sub('[!?]','',x)
    return x

def clean_chn(x):
    x = re.sub('[!?！？\n]','',x)
    x = jieba.cut(x)
    return ' '.join(x)

# %%
for i in range(len(en_sentences)):
    # Add <s> start and <e> end to the each target sentence  
    en_sentences[i] = clean_eng(en_sentences[i])
    cn_sentences[i] = "<s> " + clean_chn(cn_sentences[i].replace(" ","")) + " <e>"
    
    if len(en_sentences[i].split()) <= max_len and len(cn_sentences[i].split()) <= max_len:
        en_list.append(en_sentences[i])
        cn_list.append(cn_sentences[i])
        
print("lenght of Source:", len(en_list))
print("Source: ", en_list[0])

print("lenght of Target sentences:", len(cn_list))
print("Target: ", cn_list[0])
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.044 seconds.
# Prefix dict has been built succesfully.
# lenght of Source: 200884
# Source:  this is bill lange . i 'm dave gallo .
# lenght of Target sentences: 200884
# Target:  <s> 大卫 . 盖罗 ： 这位 是 比尔 . 兰格 ， 我 是 大卫 . 盖罗 。 <e>

# %%
for i in range(5):
    print(en_list[i])
    print(cn_list[i])
# Out:
# this is bill lange . i 'm dave gallo .
# <s> 大卫 . 盖罗 ： 这位 是 比尔 . 兰格 ， 我 是 大卫 . 盖罗 。 <e>
# and we 're going to tell you some stories from the sea here in video .
# <s> 我们 将 用 一些 影片 来 讲述 一些 深海 里 的 故事 。 <e>
# we 've got some of the most incredible video of titanic that 's ever been seen , and we 're not going to show you any of it .
# <s> 我们 这有 不少 精彩 的 泰坦尼克 的 影片 ， 可惜 您 今天 看不到 。 <e>
# the truth of the matter is that the titanic -- even though it 's breaking all sorts of box office records -- it 's not the most exciting story from the sea .
# <s> 泰坦尼克号 是 拿 了 不少 票房 冠军 但 事实上 它 并 不是 关于 海洋 的 最 刺激 的 故事 。 <e>
# and the problem , i think , is that we take the ocean for granted .
# <s> 原因 在于 我们 一直 没 把 海洋 当 回事儿 。 <e>

# %% [markdown]
# ### 1.3 Split sentence into words

# %%
en_words_counter = collections.Counter([word for sentence in en_list for word in sentence.split()])
cn_words_counter = collections.Counter([word for sentence in cn_list for word in sentence.split()])

print('{} English words.'.format(len([word for sentence in en_sentences for word in sentence.split()])))
print('{} unique English words.'.format(len(en_words_counter)))
print('20 Most common words in the English dataset:')
print('"' + '" "'.join(list(zip(*en_words_counter.most_common(20)))[0]) + '"')
print("---------------------------------------------------------------------------------------------------------------")
print('{} Chinese words.'.format(len([word for sentence in cn_sentences for word in sentence.split()])))
print('{} unique Chinese words.'.format(len(cn_words_counter)))
print('20 Most common words in the Chinese dataset:')
print('"' + '" "'.join(list(zip(*cn_words_counter.most_common(20)))[0]) + '"')
# Out:
# 4250820 English words.
# 55163 unique English words.
# 20 Most common words in the English dataset:
# "," "." "the" "and" "to" "of" "a" "that" "i" "it" "in" "you" "we" "is" "'s" "this" "so" """ "they" "was"
# ---------------------------------------------------------------------------------------------------------------
# 4180600 Chinese words.
# 82572 unique Chinese words.
# 20 Most common words in the Chinese dataset:
# "的" "<s>" "<e>" "，" "。" "我" "我们" "是" "在" "了" "你" """ "一个" "这" "有" "他们" "和" "就" "它" "这个"

# %% [markdown]
# ### 1.4 Split data into training and testing set

# %%
### Split the preccessed data into training and test sets using Sklearn ###
en_train, en_test, cn_train, cn_test = train_test_split(np.array(en_list), 
                                                        np.array(cn_list), 
                                                        test_size=0.1, 
                                                        random_state=42,
                                                        shuffle = True)

# %%
print("en_train.shape: ", en_train.shape)
print("en_test.shape: ", en_test.shape)
print("cn_train.shape: ", cn_train.shape)
print("cn_test.shape: ", cn_test.shape)
# Out:
# en_train.shape:  (180795,)
# en_test.shape:  (20089,)
# cn_train.shape:  (180795,)
# cn_test.shape:  (20089,)

# %% [markdown]
# ## 2. Tokenize and Padding

# %% [markdown]
# ### 2.1 Tokenize English and Chinese sentences

# %%
def tokenize(texts, maxlen, num_words):
    tokenizer = Tokenizer(filters='',num_words = num_words, oov_token = '<unk>')
    tokenizer.fit_on_texts(texts)
    vocab_size = len(tokenizer.index_word) + 1
    max_len = max(list(map(lambda i: len(i.split()), texts)))
    max_len =  min(max_len, maxlen)
    vocab_size = min(vocab_size, num_words)

    seqs = tokenizer.texts_to_sequences(texts)
    padded_seqs = pad_sequences(seqs, max_len, padding='post')
    return tokenizer, vocab_size, max_len, padded_seqs

# %%
# Create English tokeninzer for training set
src_tokenizer, src_vocab_size, src_max_len, en_input_seq = \
tokenize(en_train, max_len, en_vocab_size)

# %%
print("src_tokenizer.index_word: ", len(src_tokenizer.index_word))
print("src_vocab_size: ", src_vocab_size)
print("src_max_len: ", src_max_len)
print("en_input_seq.shape: ", en_input_seq.shape)
print("en_input_seq: ", en_input_seq)
# Out:
# src_tokenizer.index_word:  52939
# src_vocab_size:  50000
# src_max_len:  50
# en_input_seq.shape:  (180795, 50)
# en_input_seq:  [[   5    8  132 ...    0    0    0]
#  [  10  222   11 ...    0    0    0]
#  [ 340    2   14 ...    0    0    0]
#  ...
#  [  48 3818    9 ...    3    0    0]
#  [   5   17   15 ...    0    0    0]
#  [  26   35   20 ...    0    0    0]]

# %%
# Create Chinese tokeninzer
tar_tokenizer, tar_vocab_size, tar_max_len, de_input_seq = \
tokenize(cn_train, max_len, cn_vocab_size)

# %%
print("tar_tokenizer length: ", len(tar_tokenizer.index_word))
print("tar_tokenizer.index_word: ", tar_tokenizer.index_word[10])
print("tar_vocab_size: ", tar_vocab_size)
print("tar_max_len: ", tar_max_len)
print("de_input_seq.shape: ", de_input_seq.shape)
print("de_input_seq: ", de_input_seq)
# Out:
# tar_tokenizer length:  78590
# tar_tokenizer.index_word:  在
# tar_vocab_size:  10000
# tar_max_len:  50
# de_input_seq.shape:  (180795, 50)
# de_input_seq:  [[   3  102  878 ...    0    0    0]
#  [   3    7   10 ...    4    0    0]
#  [   3  658  133 ...    0    0    0]
#  ...
#  [   3   24  108 ... 1243    6    4]
#  [   3   15   25 ...    0    0    0]
#  [   3   40   66 ...    0    0    0]]

# %%
print(tar_tokenizer.index_word[12])
# Out:
# 你

# %%
de_target_seq = de_input_seq[:,1:]
print("de_target_seq.shape: ", de_target_seq.shape)
print("de_target_seq: ", de_target_seq)
# Out:
# de_target_seq.shape:  (180795, 49)
# de_target_seq:  [[ 102  878   22 ...    0    0    0]
#  [   7   10  212 ...    4    0    0]
#  [ 658  133   35 ...    0    0    0]
#  ...
#  [  24  108 3411 ... 1243    6    4]
#  [  15   25  277 ...    0    0    0]
#  [  40   66   68 ...    0    0    0]]

# %%
de_input_seq = de_input_seq[:,:-1]

print("de_input_seq.shape: ", de_input_seq.shape)
print("de_input_seq: ", de_input_seq)
# Out:
# de_input_seq.shape:  (180795, 49)
# de_input_seq:  [[   3  102  878 ...    0    0    0]
#  [   3    7   10 ...   13    4    0]
#  [   3  658  133 ...    0    0    0]
#  ...
#  [   3   24  108 ...  294 1243    6]
#  [   3   15   25 ...    0    0    0]
#  [   3   40   66 ...    0    0    0]]

# %%
print('max len: ' + str((src_max_len, tar_max_len)))
print('vocab size: ' + str((src_vocab_size, tar_vocab_size)))
# Out:
# max len: (50, 50)
# vocab size: (50000, 10000)

# %%
print(de_target_seq.shape)
print(tar_vocab_size)

del en_sentences
del cn_sentences
# Out:
# (180795, 49)
# 10000

# %%
de_target_matrix = to_categorical(de_target_seq, tar_vocab_size)

# %%
print(de_target_matrix.shape)
# Out:
# (180795, 49, 10000)

# %% [markdown]
# ## 3. Callback Functions

# %% [markdown]
# ### 3.1 Reduce learning rate when a metric has stopped improving
# Now, we start defining callback functions...

# %%
lr_reducer = ReduceLROnPlateau(monitor='val_loss', 
                               factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=2, 
                               min_lr=1e-6)

# %% [markdown]
# ### 3.2 Model checkpoint

# %%
save_dir = os.getcwd()
weight_path = './weight/lstm.h5'

# model.save(model_path)
print('Model Path at %s ' % weight_path)

# Save the model after every epoch if model improves
model_checkpoint = ModelCheckpoint(weight_path, 
                                   monitor="val_acc", 
                                   save_best_only=True,
                                   save_weights_only=True, 
                                   verbose=1)
# Out:
# Model Path at ./weight/lstm.h5

# %% [markdown]
# ### 3.3 Early Stop

# %%
early_stopping = EarlyStopping(monitor='val_loss', 
                               patience=4, 
                               verbose=1)

# %% [markdown]
# ### 3.4 Monitor Learning Rate for every epoch

# %%
history_lr = []  # Variable to store leraning rate history

class MonitorLR(tf.keras.callbacks.Callback):   
    def on_epoch_end(self, epoch, logs=None):
        print("\n")
        print("Learning Rate:", K.eval(self.model.optimizer.lr))
        print("\n")
        history_lr.append(K.eval(self.model.optimizer.lr))
              
monitorLR = MonitorLR()

# %% [markdown]
# ### 3.5 Callback function
# To be applied at given stages of the training procedure.

# %%
callbacks=[lr_reducer,
           monitorLR, 
           model_checkpoint,
           early_stopping]

# %% [markdown]
# ## 4. Model
# ### 4.1 Build Model

# %%
print("Now, creating model...")
#======== model paramters =======
latent_dim = 1024
#======== train paramters =======
#epochs = 100
epochs = 30
batch_size = 128
#================================
# Out:
# Now, creating model...

# %% [markdown]
# ### 4.2 Encoder model

# %%
print("Creating Encoder Model...")
enc_input = Input((None,), name = 'en_input_seq')
enc_embed = Embedding(src_vocab_size + 1, latent_dim, name = 'encoder_embed')
encoder = LSTM(latent_dim, return_state=True, name = 'encoder')

enc_z, enc_state_h, enc_state_c = encoder(enc_embed(enc_input))
enc_states = [enc_state_h, enc_state_c]
enc_model = Model(enc_input, enc_states)

print("enc_model: ", enc_model.summary())
# Out:
# Creating Encoder Model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# en_input_seq (InputLayer)    (None, None)              0
# _________________________________________________________________
# encoder_embed (Embedding)    (None, None, 1024)        51201024
# _________________________________________________________________
# encoder (LSTM)               [(None, 1024), (None, 102 8392704
# =================================================================
# Total params: 59,593,728
# Trainable params: 59,593,728
# Non-trainable params: 0
# _________________________________________________________________
# enc_model:  None

# %% [markdown]
# ### 4.3 Decoder model

# %%
print("Creating Decoder Model...")
dec_input = Input((None,), name = 'de_input_seq')
dec_state_h_input = Input((latent_dim,), name = 'decoder_input_state_h')
dec_state_c_input = Input((latent_dim,), name = 'decoder_input_state_c')
dec_states_input = [dec_state_h_input, dec_state_c_input]

dec_embed = Embedding(tar_vocab_size + 1, latent_dim, name = 'decoder_embed')
decoder = LSTM(latent_dim, return_state=True, return_sequences=True, name = 'decoder')
dec_fc = TimeDistributed(Dense(tar_vocab_size, activation='softmax'), name = 'decoder_output')

dec_z, dec_state_h, dec_state_c = decoder(dec_embed(dec_input), initial_state = dec_states_input)
dec_states_output = [dec_state_h, dec_state_c]
dec_output = dec_fc(dec_z)

dec_model = Model([dec_input]+dec_states_input, [dec_output]+dec_states_output)

print("dec_model: ", dec_model.summary())
# Out:
# Creating Decoder Model...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# de_input_seq (InputLayer)       (None, None)         0
# __________________________________________________________________________________________________
# decoder_embed (Embedding)       (None, None, 1024)   10241024    de_input_seq[0][0]
# __________________________________________________________________________________________________
# decoder_input_state_h (InputLay (None, 1024)         0
# __________________________________________________________________________________________________
# decoder_input_state_c (InputLay (None, 1024)         0
# __________________________________________________________________________________________________
# decoder (LSTM)                  [(None, None, 1024), 8392704     decoder_embed[0][0]
#                                                                  decoder_input_state_h[0][0]
#                                                                  decoder_input_state_c[0][0]
# __________________________________________________________________________________________________
# decoder_output (TimeDistributed (None, None, 10000)  10250000    decoder[0][0]
# ==================================================================================================
# Total params: 28,883,728
# Trainable params: 28,883,728
# Non-trainable params: 0
# __________________________________________________________________________________________________
# dec_model:  None

# %% [markdown]
# ### 4.4 Encoder_decoder training model

# %%
print("Creating Encoder_decoder Model...")
tar_logit, _, _ = decoder(dec_embed(dec_input), initial_state= enc_states)
tar_output = dec_fc(tar_logit)

enc_dec_model = Model([enc_input, dec_input], tar_output)


if not os.path.exists('./weight/'):
    os.mkdir('./weight/')
    
try:
    enc_dec_model.load_weights(weight_path)
    print('load from previous model')
except:
    print('train a new model')    

optimizer = tf.keras.optimizers.Adam(lr = 0.001,
                                     beta_1=0.9, 
                                     beta_2=0.999, 
                                     amsgrad=False)

enc_dec_model.compile(loss = 'categorical_crossentropy',
                      optimizer= optimizer,
                      metrics=['accuracy'])

#  model summary
enc_dec_model.summary()

print("Done")
# Out:
# Creating Encoder_decoder Model...
# load from previous model
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# en_input_seq (InputLayer)       (None, None)         0
# __________________________________________________________________________________________________
# de_input_seq (InputLayer)       (None, None)         0
# __________________________________________________________________________________________________
# encoder_embed (Embedding)       (None, None, 1024)   51201024    en_input_seq[0][0]
# __________________________________________________________________________________________________
# decoder_embed (Embedding)       (None, None, 1024)   10241024    de_input_seq[0][0]
# __________________________________________________________________________________________________
# encoder (LSTM)                  [(None, 1024), (None 8392704     encoder_embed[0][0]
# __________________________________________________________________________________________________
# decoder (LSTM)                  [(None, None, 1024), 8392704     decoder_embed[1][0]
#                                                                  encoder[0][1]
#                                                                  encoder[0][2]
# __________________________________________________________________________________________________
# decoder_output (TimeDistributed (None, None, 10000)  10250000    decoder[1][0]
# ==================================================================================================
# Total params: 88,477,456
# Trainable params: 88,477,456
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Done

# %% [markdown]
# ### 4.5 Model Structure

# %%
# Save model as image
plot_model(enc_dec_model, 
           "./images/model.png", 
           show_shapes=True, 
           show_layer_names=True)

print("Done!")
# Out:
# Done!

# %%
# %pylab inline
import matplotlib.image as mpimg
img=mpimg.imread('./images/model.png')

plt.figure(figsize = (20,15))
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /root/miniconda3/envs/new/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['maximum', 'add', 'average', 'minimum', 'multiply', 'subtract', 'dot', 'concatenate']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ### 4.6 Fit Model

# %%
history = enc_dec_model.fit([en_input_seq, de_input_seq], 
                            de_target_matrix,
                            batch_size=batch_size,
                            epochs=epochs, 
                            shuffle = True,
                            callbacks = callbacks,
                            validation_split = 0.1)
# Out:
# /root/miniconda3/envs/new/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 162715 samples, validate on 18080 samples
# Epoch 1/30
# 162688/162715 [============================>.] - ETA: 0s - loss: 0.9259 - acc: 0.8063
#
# Learning Rate: 0.001
#
#
#
# Epoch 00001: val_acc improved from -inf to 0.76048, saving model to ./weight/lstm.h5
# 162715/162715 [==============================] - 900s 6ms/step - loss: 0.9260 - acc: 0.8063 - val_loss: 1.3982 - val_acc: 0.7605
# Epoch 2/30
# 162688/162715 [============================>.] - ETA: 0s - loss: 0.8206 - acc: 0.8212
#
# Learning Rate: 0.001
#
#
#
# Epoch 00002: val_acc did not improve from 0.76048
# 162715/162715 [==============================] - 893s 5ms/step - loss: 0.8206 - acc: 0.8212 - val_loss: 1.4390 - val_acc: 0.7586
# Epoch 3/30
# 162688/162715 [============================>.] - ETA: 0s - loss: 0.7314 - acc: 0.8358
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00003: val_acc did not improve from 0.76048
# 162715/162715 [==============================] - 895s 6ms/step - loss: 0.7314 - acc: 0.8358 - val_loss: 1.4869 - val_acc: 0.7560
# Epoch 4/30
# 162688/162715 [============================>.] - ETA: 0s - loss: 0.5681 - acc: 0.8699
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00004: val_acc did not improve from 0.76048
# 162715/162715 [==============================] - 892s 5ms/step - loss: 0.5681 - acc: 0.8699 - val_loss: 1.5256 - val_acc: 0.7556
# Epoch 5/30
# 162688/162715 [============================>.] - ETA: 0s - loss: 0.4877 - acc: 0.8901
#
# Learning Rate: 0.000100000005
#
#
#
# Epoch 00005: val_acc did not improve from 0.76048
# 162715/162715 [==============================] - 896s 6ms/step - loss: 0.4877 - acc: 0.8901 - val_loss: 1.5779 - val_acc: 0.7531
# Epoch 00005: early stopping

# %% [markdown]
# ## 5. Evaluate Model
# ### 5.1 Load Weight

# %%
print("Now, we start evaluating the model...")
# Load weight
print(weight_path)
enc_dec_model.load_weights(weight_path)
print("Weights were loaded!")
# Out:
# Now, we start evaluating the model...
# ./weight/lstm.h5
# Weights were loaded!

# %% [markdown]
# ### 5.2 Score training set

# %%
scores_train = enc_dec_model.evaluate([en_input_seq, de_input_seq], 
                                       de_target_matrix,
                                       verbose=1)

print('Train loss:', scores_train[0])
print('Train accuracy:', scores_train[1])
# Out:
# 180795/180795 [==============================] - 853s 5ms/step
# Train loss: 0.8369586708937412
# Train accuracy: 0.8239816098258823

# %% [markdown]
# ### 5.3 Score test data

# %%
# Tokenize and pad testing set
en_seqs = src_tokenizer.texts_to_sequences(en_test)
en_input_seq_test = pad_sequences(en_seqs, src_max_len, padding='post')

cn_seqs = tar_tokenizer.texts_to_sequences(cn_test)
de_input_seq_test = pad_sequences(cn_seqs, tar_max_len, padding='post')

de_target_seq_test = de_input_seq_test[:,1:]
de_input_seq_test = de_input_seq_test[:,:-1]

de_target_matrix_test = to_categorical(de_target_seq_test, tar_vocab_size)

# %%
print('en_input_seq_test.shape:', en_input_seq_test.shape)
print('de_input_seq_test.shape:', de_input_seq_test.shape)
print('de_target_seq_test.shape:', de_target_seq_test.shape)
# Out:
# en_input_seq_test.shape: (20089, 50)
# de_input_seq_test.shape: (20089, 49)
# de_target_seq_test.shape: (20089, 49)

# %%
scores_test = enc_dec_model.evaluate([en_input_seq_test, de_input_seq_test], 
                                     de_target_matrix_test,
                                     verbose=1)

print('Test loss:', scores_test[0])
print('Test accuracy:', scores_test[1])
# Out:
# 20089/20089 [==============================] - 102s 5ms/step
# Test loss: 1.3774980361930786
# Test accuracy: 0.7628146587980471

# %% [markdown]
# ### 5.4 Accuracy and Loss Trend

# %%
print("Now, we start drawing the loss and acc trends graph...")  
    
# Summarize history for accuracy 
fig = plt.figure(figsize=(10,5))
plt.plot(history.history["acc"])  
plt.plot(history.history["val_acc"])  
plt.title("Accuracy")  
plt.ylabel("accuracy")  
plt.xlabel("epoch")  
plt.legend(["train","eva"],loc="upper left")  
plt.show()
    
# Summarize history for loss
fig = plt.figure(figsize=(10,5))     
plt.plot(history.history["loss"])  
plt.plot(history.history["val_loss"])  
plt.title("Loss")  
plt.ylabel("loss")  
plt.xlabel("epoch")  
plt.legend(["train","eva"],loc="upper left")  
plt.show()
# Out:
# Now, we start drawing the loss and acc trends graph...

# %% [markdown]
# ### 5.5 Learning Rate

# %%
#summarize history for Learning rate
fig = plt.figure(figsize=(10,5))     
plt.plot(history_lr, label="lr")
plt.title("Learning Rate")  
plt.ylabel("Learning Rate")  
plt.xlabel("epoch")  
plt.legend()  
plt.show()

# %% [markdown]
# ## 6. Translate Samples

# %%
import pandas as pd
df = pd.read_csv('./data/cmn.txt',sep='\t', header=None, names = ['en','cn'])
df.head()
# Out:
#        en     cn
# 0     Hi.     嗨。
# 1     Hi.    你好。
# 2    Run.  你用跑的。
# 3   Wait!    等等！
# 4  Hello!    你好。

# %%
def _init_states(enc_model, src_sentence, tokenizers, src_max_len):
    """generate the states from encoder
    Args:
        enc_model
        src_sentence
        tokenizers: tuple (src_tokenizer, tar_tokenizer)
        src_max_len
    Return:
        tuple (target_triple, initial_states)
    """
    src_tokenizer, tar_tokenizer = tokenizers
    src_index_word = src_tokenizer.index_word
    src_word_index = src_tokenizer.word_index 
    tar_index_word = tar_tokenizer.index_word
    tar_word_index = tar_tokenizer.word_index
    tar_token = '<s>'
    tar_index = tar_word_index.get(tar_token, None)
    if tar_index == None:
        print('start token <s> not found!')
    src_input_seq = src_tokenizer.texts_to_sequences([src_sentence])
    src_input_seq = pad_sequences(src_input_seq, maxlen=src_max_len, padding='post')
    states = enc_model.predict(src_input_seq)
    return ([tar_index], [tar_token], [1.0]), states

# %%
def _update_states(dec_model, tar_triple, states, tokenizers):
    """ update the decoder states
    Args:
        dec_model
        tar_triple: (target index[list], target_token[list], target_probability[list])
        states:
        params:
    Return:
        tuple (tar_triple, states)
    """
    src_tokenizer, tar_tokenizer = tokenizers
    src_index_word = src_tokenizer.index_word
    src_word_index = src_tokenizer.word_index 
    tar_index_word = tar_tokenizer.index_word
    tar_word_index = tar_tokenizer.word_index
    tar_index, tar_token, tar_prob = tar_triple
    # predict the token probability, and states
    probs, state_h, state_c = dec_model.predict([[tar_index[-1]]] + states)
    states_new = [state_h, state_c]
    # update the triple
    # greedy search: each time find the most likely token (last position in the sequence)
    probs = probs[0,-1,:]
    tar_index_new = np.argmax(probs)
    tar_token_new = tar_index_word.get(tar_index_new, None)
    tar_prob_new = probs[tar_index_new]
    tar_triple_new = ( 
        tar_index + [tar_index_new],
        tar_token + [tar_token_new],
        tar_prob + [tar_prob_new]
        )
    return tar_triple_new, states_new

# %%
def infer_lstm(src_sentence, enc_model, dec_model, tokenizers, max_len = (9,14)):
    """infer the seq2seq model
    Args:
        src_sentence
        enc_model
        dec_model
        tokenizers,
        max_len
    Return:
        decoded sentence
    """
    src_max_len, tar_max_len = max_len
    # initialize with encoder states
    tr, ss = _init_states(enc_model, src_sentence, tokenizers, src_max_len)
    for i in range(tar_max_len):
        # update the triple and states
        tr, ss = _update_states(dec_model, tr, ss, tokenizers)
        if tr[1][-1] == '<e>' or tr[1][-1] == None:
            break
     
    return ''.join(tr[1])

# %%
for i in range(100,710):
    src_raw = en_test[i]
    #src_raw = df.en.values[i]
    src = clean_eng(src_raw)
    #print("src:", src)
    #src = "And we really have this incredibly simplistic view of why people work and what the labor market looks like."
    dec = infer_lstm(src, enc_model, dec_model, (src_tokenizer, tar_tokenizer),(50,49))
    print('[%s] => [%s]'%(src,dec))
    print("")
# Out:
# [and if you look at the 36 countries with the highest burden of malnutrition , that 's 260 billion lost from a productive economy every year .] => [<s>如果你把撒哈拉以南的国家<unk><unk>，<unk>亿美元每年都会增长到<unk>。<e>]
#
# [so if you don 't have an endgame of something delightful , then you 're just moving chess pieces around , if you don 't know you 're taking the king .] => [<s>如果你不知道<unk>的<unk>，你就会发现一个<unk>，你就会把自己<unk>一个<unk>。<e>]
#
# [i was still in deep grief ; i knew i didn 't have the strength .] => [<s>我仍然<unk>，我<unk>。<e>]
#
# [so why do we need commitment devices ] => [<s>为什么我们需要的是什么呢<e>]
#
# [but this is not just about students sitting alone in their living room working through problems .] => [<s>而这不仅仅是在<unk>里<unk>的人，也是他们的生活环境。<e>]
#
# [we actually have a couple of other planets in this solar system .] => [<s>事实上我们还有行星的光谱系统也能做到<e>]
#
# [they don 't like that . they think it 's crank . i don 't think it 's crank .] => [<s>他们不会觉得，他们认为我是个<unk>。我认为这不是偶然。<e>]
#
# [my own interest in this subject , and my passion for it , began rather accidentally .] => [<s>我对这个定义的兴趣感到兴奋，而且<unk>的开头，以及开始的。<e>]
#
# [but the fact of the matter is that what is going on is a kind of emergent complexity .] => [<s>但真正的观点是，这是种<unk>的循环。<e>]
#
# [most people have cooking fires in the world , whether it 's camel dung or wood .] => [<s>大多数人都会<unk>世界上的<unk>，比如，<unk>，<e>]
#
# [and i also was taught , coupled with that , that it was my job -- this classroom full of five and six year-old children -- it was our job , apparently , to help .] => [<s>我也有这样的想法--我的工作就是--<unk>和我的团队--<unk>，<unk>，<unk>-----------------------]
#
# [and the answer is : i got them from flickr .] => [<s>答案是：我从<unk><unk>了。<e>]
#
# [there 's going to be unintended consequences .] => [<s>接下来会有什么后果<e>]
#
# [thank you .] => [<s>谢谢。<e>]
#
# [he said -- think about this one .] => [<s>他说到，这个问题<e>]
#
# [fs : my job ends here , and the nollywood filmmakers really have now to work .] => [<s>我的工作是<unk>的，<unk>的作品，都是由<unk>的作品制作的。<e>]
#
# [she too mines the rich source material of amar chitra kathas , but in a very different way than chitra ganesh .] => [<s>她也不擅长<unk><unk>，但是在<unk>中<unk>，但是<unk>的<unk><unk>的<unk>。<e>]
#
# [we 'd like to know these things .] => [<s>我们想知道这些东西是什么。<e>]
#
# [and the second , with an impulse every other note .] => [<s>第二，<unk>的每一个音符都是<unk>的。<e>]
#
# [you know , how on earth did they know all this ] => [<s>你知道怎么知道这些怎么能做到这些呢<e>]
#
# [it all goes in suitcases .] => [<s>所有的这些都在<unk>中<e>]
#
# [back to back is an australian company of people with intellectual disabilities . i saw their amazing show in new york at the staten island ferry terminal at rush hour .] => [<s>回到澳大利亚的<unk>，我看到了<unk><unk>的<unk>，<unk><unk><unk>的<unk><unk><unk>的<unk>。<e>]
#
# [and they do wonderful things .] => [<s>它们很好。<e>]
#
# [they have to learn to accept it and gradually turn this into positive energy .] => [<s>他们必须接受到<unk>的生活，然后把它<unk>。<e>]
#
# [can you say it with me ] => [<s>你能说我是个怪吗<e>]
#
# [so the first project , which will be built next summer , is an open-air farmers ' market downtown , followed by bus shelters for the school bus system in the second year and home improvements for the elderly in the third year .] => [<s>第一个项目是第一个项目，在<unk><unk>，她将<unk><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk>学校。<e>]
#
# [so , i took a look at my life , a hard look at my life , and i saw some things very disturbing .] => [<s>所以，我看着生命，我的生活充满了我的内心，我觉得非常非常舒服。<e>]
#
# [so how might we prepare for some of these specific threats , like attacking a president or a prime minister ] => [<s>那么我们应该如何应对这些攻击的危险尤其是在<unk>或<unk>的情况下，我们对这个问题<e>]
#
# [so how can we change this dynamic ] => [<s>我们如何改变这种改变<e>]
#
# [anyway , he was just like all the rest of them .] => [<s><unk>，他们都是<unk>。<e>]
#
# [so we 're seeing huge numbers of diversity in the kinds of things .] => [<s>我们看到了大量的多样性多样性。<e>]
#
# [that 's not dirty enough . let 's just stir that up a little bit .] => [<s>这不是<unk>。我们要把一个<unk><unk>。<e>]
#
# [thank you .] => [<s>谢谢。<e>]
#
# [if you make people self-conscious about their judgments , studies show you will make them make worse judgments .] => [<s>如果你让人们做一些<unk>的<unk>，你会变得更擅长做这些事情。<e>]
#
# [we asked him if he would send his daughters as well as his sons .] => [<s>我们问他如果他能把他的儿子<unk><unk>。<e>]
#
# [this also turns out to be the best way to cope with global challenges -- climate change , nuclear proliferation , energy insecurity , energy poverty -- all of which make us less safe .] => [<s>而且，这个世界上的挑战是我们可以面对的，能源作物的能源，我们的能源作物，<unk>，<unk>，能源作物，我们的国家都会改变。<e>]
#
# [this is actually easter island . look at this monster .] => [<s>这是<unk>，在<unk>的时候，<e>]
#
# [and i just simply say , " hardly . "] => [<s>我只是说，"<unk>的。"<e>]
#
# [that 's how we churn those products out .] => [<s>那就是我们如何设计这些产品的<e>]
#
# [and so i placed one more element of each one of them .] => [<s>我把它们都放在一个更小的<unk>里<e>]
#
# [the result of all this is that you can get incredibly quick progress on incredibly small budgets .] => [<s>这个项目的小范围内的成本实际上是小的成本效益<e>]
#
# [tell a little bit about what you 're wearing on your leg .] => [<s>说说你的<unk>是你的腿<unk>。<e>]
#
# [you have to cut it out , bring it back home , cut it up , look inside and say , " oh yes , it does have gas . "] => [<s>你必须把它<unk>，把它<unk>，然后<unk>，"噢，<unk>，<unk>。"<e>]
#
# [we 're going to have -- -- we 're going to have to live closer to where we work .] => [<s>我们必须要--我们要去探索的地方。<e>]
#
# [and purchasing for progress today is in 21 countries .] => [<s>这是21世纪的<unk>分布在21世纪。<e>]
#
# [don 't worry , i 'm not going to call anyone in particular out on any aspects of your own mistakes .] => [<s>不用担心，我不会在任何时候都能<unk><unk><e>]
#
# [they did the best they could given that this is what they 're writing for .] => [<s>他们尽了最大的努力来做这个。<e>]
#
# [the lesson of the titanic , for a lot of the contemporaries , was that you must have enough lifeboats for everyone on the ship .] => [<s><unk>中的许多<unk>中的许多人都认为，<unk><unk>的人必须<unk>。<e>]
#
# [on this particular evening , i came across this live band dressed to the t in their coordinating outfits .] => [<s>在那天，我去了<unk>的<unk><unk><unk>的<unk><e>]
#
# [the conclusion from their experiment was that the slime mold had a primitive form of intelligence .] => [<s>这项研究的实验是做实验的"<unk>"<unk>的<unk><e>]
#
# [with these sacrifices , greece did avoid bankruptcy and the eurozone avoided a collapse .] => [<s>而且随着<unk>的<unk>，<unk>的<unk>和<unk><unk>变得<unk><unk>。<e>]
#
# [they 're under constant mechanical forces .] => [<s>它们在<unk>中<unk>。<e>]
#
# [and as the victims ' families and the city and the country reeled in shock , investigators tried to find out who was responsible .] => [<s>而那些<unk>和<unk>的人，和<unk>的学生一起<unk>，他们发现了自己的<unk>。<e>]
#
# [i think if you treat people well , people will come back and come back for more .] => [<s>我想人们<unk>，<unk>，你就会得到回报。<e>]
#
# [so much so that i don 't think i had ever really had foie gras until that moment .] => [<s>所以我觉得我已经<unk>了<unk>的<unk>了<e>]
#
# [and so to me the question is not whether these dynamics will continue the way they have .] => [<s>所以我想问这些问题并不是什么<unk>的方式。<e>]
#
# [we 've got lots of people , pollution , cars , concrete , lots of concrete .] => [<s>我们有各种各样的<unk>，<unk>，<unk>，<unk>。<e>]
#
# [right now , we are just at the turning point .] => [<s>现在我们正处于<unk>中。<e>]
#
# [and i have an oasis .] => [<s>我有<unk><e>]
#
# [you see , this will be an entirely new global data set .] => [<s>你看，这是一个全球的海量数据。<e>]
#
# [nurses getting better training , pharmacists being able to order supplies , doctors sharing their expertise in all aspects of medicine .] => [<s>护士、护士、训练医生们能够训练自己的身体来帮助他们的父母及<unk>。<e>]
#
# [but most important to make it work -- and he emphasized this -- is that it took knowing the people in the communities .] => [<s>但是最重要的是--这是个重要的问题--他正在试图去理解这些社区的<unk>。<e>]
#
# [after this big expansion , you 've seen no net increase in injuries , and so there is something to that axiom that there is safety in numbers .] => [<s>在这个规模的范围内，你会得到大量的<unk>，这意味着，你会得到大量的<unk>，这将会是<unk>的。<e>]
#
# [it 's about how many shining eyes i have around me .] => [<s>我的眼睛是有多少<unk>的<e>]
#
# [and they , in fact , covered the same 24 news events .] => [<s>实际上，他们同样的<unk>同样的<unk>。<e>]
#
# [you think , " what can i add to the system to create more value  "] => [<s>你认为，"我们能把它<unk>为"<unk><unk>的价值"<e>]
#
# [one : curved tips can maximize the springiness when you draw and shoot the arrow .] => [<s>第一，<unk><unk>的<unk>，当你把它<unk><unk>。<e>]
# [and he walked in , and somebody said something to him , we realized he was deaf , and we looked into the rags , and there was this pair of eyes .] => [<s>他走到那里，然后他<unk>，我们把他的<unk><unk>，我们发现了一个<unk>，他<unk>了。<e>]
#
# [actually , reduce your amount of light exposure at least half an hour before you go to bed .] => [<s>实际上，在你的<unk>上至少有300小时的时间才能每天燃烧<e>]
#
# [they kind of have a sixth sense like superman 's x-ray vision .] => [<s>它们看上去像是<unk>的<unk>，是一只<unk>的x射线<e>]
#
# [you don 't punish failure . you reward every little bit of effort -- a little bit of gold , a little bit of credit . you 've done 20 questions -- tick .] => [<s>你不需要<unk>，你就<unk><unk>，<unk>，<unk>，<unk>，你有很多的<unk>，你可以得到很多的回报。<e>]
#
# [what we actually want to do is we want to take your email and turn it into something that looks more like this , but more importantly , we want to do it in a way that you can 't even tell that it 's happened .] => [<s>我们希望能够做的是，你想要做一个更加<unk>的事情，你可以看到我们的<unk>，但我们却无法理解它。<e>]
#
# [so we didn 't really have that many hurdles , i have to say , with the government and all the authorities .] => [<s>所以我们没有太多，我的<unk>，我们必须与政府合作，<e>]
#
# [i loved to write from the age of four , and when i was six my mom bought me my own laptop equipped with microsoft word .] => [<s>我记得高中是20岁的，我的女儿写了<unk>，我的书是<unk>的。<e>]
#
# [so let 's see what happens when we put this beetle to the test with a similar experiment .] => [<s>让我们来看看这个实验会发生什么呢我们会把这个问题放在一个<unk>上。<e>]
#
# [and you don 't have to be a mega-hero .] => [<s>你不必<unk><unk>。<e>]
#
# [third , adapting to rising seas .] => [<s>第三，<unk>在一起，<e>]
#
# [that 's worse than not having him here at all . "] => [<s>这比他比这还要糟糕。"<e>]
#
# [i mean , it was incredible innovation .] => [<s>我的意思是，这是一个非常强大的创新之处。<e>]
#
# [go space , space . it is totally amazing .] => [<s>空间空间。这是一个非常美妙的地方。<e>]
#
# [you know , we just celebrated , this year , our general elections , the biggest exercise in democratic franchise in human history .] => [<s>我们刚刚<unk>，<unk>，<unk>是民主在<unk>年的民主<unk>的年代<e>]
#
# [this is normally when people start kind of shuffling in their pockets trying to turn their phones onto airplane mode desperately .] => [<s>通常人们会在<unk>的时候<unk>他们的<unk><unk>。<e>]
#
# [you know , my grandfather died many years ago when i was little , but his love for mae west lives on as a misspelling in the dna of his progeny .] => [<s>我祖父前就在我的一生中发现他的<unk>因为他的<unk>被<unk><unk><unk>了因为他的<unk>被<unk>了<e>]
#
# [they are heavy , bulky , really hard to maintain , and cost a lot of money .] => [<s>它们是<unk>的，昂贵的，昂贵的，需要大量的钱。<e>]
#
# [and this report really drives home the crux of my research .] => [<s>这项研究的<unk>是我的职业生涯<unk>。<e>]
#
# [one is " charlie wilson 's war , " with tom hanks and julia roberts .] => [<s>一个是<unk><unk><unk><unk><unk><unk><unk><unk><e>]
#
# [every monday and thursday , i 'm going use my terminal days .] => [<s>每<unk>，<unk>，我的<unk>就在我的<unk><unk>。<e>]
#
# [on wednesday , i learned from laurie garrett that i 'm definitely going to get the bird flu , and i wouldn 't be at all worried about that if we never had any contact with asia .] => [<s><unk><unk>，我就<unk><unk><unk>，<unk><unk>，没有任何其他的人都能<unk>。<e>]
#
# [rb : well , i hope it 's net actually , having -- -- i 've got it right .] => [<s>理：我也是——我希望它能<unk>--我已经<unk>了。<e>]
#
# [and you know , at the top of the list , of course , were jenny , and my son , zeb , my parents -- i didn 't want to hurt them .] => [<s>你知道的，当然，在我的<unk>中，有<unk>的学生，我的父母，我的儿子，<unk>，我<unk>。<e>]
#
# [if they break it , they will break it for everybody .] => [<s>如果他们<unk>，他们会把它<unk>。<e>]
#
# [and so this became a very famous study .] => [<s>所以这个研究成为了一个非常<unk>的研究。<e>]
#
# [[ the scientific method vs. farting around ] and it 's going on kind of like that .] => [<s>[科学]的科学]<unk><unk>，这看起来是<unk>的。<e>]
#
# [that might be true , but it 's not terribly relevant .] => [<s>也许这是个<unk>但却不是这样<e>]
#
# [we can look at what they 've done , if we look .] => [<s>我们可以看他们的情况，我们看的是什么。<e>]
#
# [" pigeon 's progress " struck me as a catchy title .] => [<s>"<unk><unk><unk>"我的<unk>是一个<unk>。<e>]
#
# [as this information started coming to people , we said things like , we don 't want to see your expense report , we don 't want to know how many holidays you 're taking , we don 't want to know where you work .] => [<s>当我们开始学习<unk>的时候，人们就不会知道我们的行为，你知道我们不想和我们的<unk>们交谈，你会发现我们的<unk>会不会<unk>。<e>]
#
# [together , these 12 components form the social progress framework .] => [<s>这些<unk>的商业计划都是由一个社会媒体所组成的<e>]
#
# [when i was seven years old and my sister was just five years old , we were playing on top of a bunk bed .] => [<s>七岁那年，我五岁的时候，我是个<unk>的<unk>。<e>]
#
# [think of the bridge as being like this platform .] => [<s>把这个系统看成是像这样的<unk><e>]
#
# [our credibility ] => [<s>我们<unk>的<unk><e>]
#
# [after three and a half hours , he looked at his watch , he 's like , " i gotta go . "] => [<s>在他的<unk><unk>，他就会看到他的脸，他说，"我想<unk>。"<e>]
#
# [and instead , what do we value ] => [<s>而我们的价值，我们的价值是什么<e>]
#
# [and that 's felony murder -- 25 to life , parole at 50 if you 're lucky , and tony 's not feeling very lucky .] => [<s>那是<unk>年的<unk><unk>，<unk><unk>，<unk>，<unk>，<unk>，你都会<unk>。<e>]
#
# [" ma 'am , i miss almost all of it . "] => [<s>"<unk>，我<unk>所有的ted。"<e>]
#
# [better put that up .] => [<s>让我们<unk><e>]
#
# [so , they finished that . and i , as you can tell , am a bashful guy .] => [<s>所以，他们就这样做了。我可以告诉你，你是个<unk>的人，<e>]
#
# [does it make a difference if warriors go to battle changing their appearance or not ] => [<s>如果他们不<unk><unk>，或者改变他们的<unk>会改变什么呢<e>]
#
# [the principle is you just need those three things -- variation , selection and heredity .] => [<s><unk>是，你认为这些东西是三种不同的，<unk>和<unk>。<e>]
#
# [but notice immediately the distinctly different curve that we achieve with the blue line .] => [<s>但是很快发现我们可以利用<unk><unk>的数据<e>]
#
# [and in africa , the remote places , it 's hard to find a good road .] => [<s>在非洲，在一个地方，<unk>的地方很好。<e>]
#
# [the balconies all move to go between those configurations , but they also disappear .] => [<s>现在都可以在<unk>中随意切换但还可以<unk><e>]
#
# [in the 1930s , richard kelly was the first person to really describe a methodology of modern lighting design .] => [<s>在<unk>年，是<unk><unk>设计的一个<unk>的<unk>。<e>]
#
# [it 's the power of an image .] => [<s>这是张<unk>的图像<e>]
#
# [that 's where you see some of the source , not from my fellow environmentalists , but from people who feel threatened by nuclear power .] => [<s>这就是你在未来看到的，你知道，我的意思是，从那些地方，没有人会被视为<unk>的威胁。<e>]
#
# [what i 'm going to show you for a couple of minutes is a facility that i built in the toughest neighborhood in pittsburgh with the highest crime rate .] => [<s>我将向大家展示的是在美国，我可以在巴西和<unk><unk>一起<unk>的<unk>。<e>]
#
# [i 'm sure all of you read about it in the newspaper , lots of tough challenges .] => [<s>我都知道你们中的很多人都在<unk>，那是<unk>的挑战。<e>]
#
# [it 's not the work i set out to do .] => [<s>我不是要做的工作。<e>]
#
# [his contemporaries made faces , like the ones you see here -- en face or three-quarters .] => [<s><unk><unk>中的人<unk>了<unk>比如<unk>的<unk><e>]
#
# [the other part of the virus has a sequence that can grow an electrode material for a battery .] => [<s>一只老鼠可以利用一个电池并将其转化为<unk>。<e>]
#
# [then these labs started doing serious problem solving -- instrumentation for agriculture in india , steam turbines for energy conversion in ghana , high-gain antennas in thin client computers .] => [<s>这些实验室的实验室开始逐渐<unk>：<unk>农业<unk>，<unk>，<unk>，<unk>，农业<unk>，在<unk><unk>的<unk>中。<e>]
#
# [about 15 years ago , i went to visit a friend in hong kong .] => [<s>大概是15年前，我去找一位朋友<e>]
#
# [had leonardo wanted to draw the vitruvian nba player , he would have needed a rectangle and an ellipse , not a circle and a square .] => [<s><unk>想要找到一个<unk>的<unk>，一个<unk><unk>，一个<unk><unk>，一个<unk><unk>。<e>]
#
# [one of my favorite brain stories described these middle-aged guys .] => [<s>我最喜欢的一个故事就是<unk>这些<unk>的故事。<e>]
#
# [for me , what 's truly sundar about the idea of task shifting , though , isn 't that it simply makes health care more accessible and affordable but that it is also fundamentally empowering .] => [<s>对我来说，这对于<unk>来说，这不仅是对的，而且，对于未来的<unk>，以及它的<unk>，以及它的<unk>，以及它的<unk>，以及它的发展。<e>]
#
# [and we were there probably 10 minutes before the managers decided to dial 911 .] => [<s>在那里，我们可以在10分钟内就能得到<unk><unk>。<e>]
#
# [and then when i took that moment to take a step back , magic .] => [<s>然后，当我回到<unk>的时候，我就<unk>了。<e>]
#
# [it 's a high-strength polymer .] => [<s>它是<unk><unk>的聚合物。<e>]
#
# [it was very obvious , from the very beginning , that she was a leader .] => [<s>从某种意义上来说，这是个很明显的出发点。<e>]
#
# [well , you get several things .] => [<s>好吧，你得到一些东西。<e>]
# [and by the end of this my arm is sore , i 've got a callus on my hand , let alone bob , whose rear end looks something more like this , like swiss cheese .] => [<s>在我的<unk><unk>，我的<unk><unk>了<unk>，<unk><unk>，<unk>，<unk>，<unk>，她也<unk><unk>。<e>]
#
# [and they start to see others doing it , and saying , " wow , i want to do that with my own money . "] => [<s>他们开始寻找一些其他的东西，比如："嘿，我想做的，我想买这些钱。"<e>]
#
# [you 've got to say that 's not enough today .] => [<s>你必须说这不是那么多。<e>]
#
# [she was taken away by authorities and placed in a psychiatric hospital , and so for the next several years will lived with his older brother until he committed suicide by shooting himself through the heart .] => [<s>她被关进监狱，<unk>了<unk>，在他的<unk>里，他的<unk>被关进监狱，而他的<unk>被<unk>得<unk>。<e>]
#
# [and the chance that some of it isn 't more intelligent than ours is also a remote idea .] => [<s>而有一个不需要的是一个聪明的人，比我们的智慧还不够。<e>]
#
# [this is a sculpture of the sun and the earth , in proportion .] => [<s>这是太阳的<unk>，太阳的<unk>。<e>]
#
# [and you turn around , and you look back into the space , and some people talk aloud .] => [<s>然后你四处<unk>，然后你就会发现一些人在谈论，<e>]
#
# [here 's a handmade mclaren slr carbon car that got t-boned by a golf .] => [<s>这是<unk>的<unk><unk><unk>的<unk><unk><unk>。<e>]
#
# [so we work with a lot of technology , but we don 't really love technology , because it gives us a lot of pain in our work over years and years .] => [<s>我们在技术的技术里，但技术的进步和技术，但是我们没有真正的帮助，因为我们的生活方式也<unk>了。<e>]
#
# [at best , he thought , it had to have been a hallucination -- a trick of the eye or the ear , perhaps , or his own mind working against him .] => [<s>他认为，他知道有一种方法，他是上帝的化身，或者是他的眼睛，或者是——或者他是<unk>。<e>]
#
# [and if we slip from the realm of the sea into the realm of the spirit of the imagination , you enter the realm of tibetan buddhism .] => [<s>如果我们把<unk>的<unk><unk>到<unk>中，它们就会被<unk><unk>。<e>]
#
# [it 's variable . it 's noisy . and , in particular , in two ways .] => [<s>有<unk>，很高的，也是<unk>，也是<unk>的。<e>]
#
# [it 's a pretty sophisticated example of computers actually understanding human language , and it actually got its knowledge by reading wikipedia and several other encyclopedias .] => [<s>这是一个广泛的例子，它是关于理解和知识的知识，它是关于<unk>和文学的知识。<e>]
#
# [and when you have low productivity in this , in ice , the productivity in copepods go down .] => [<s>在这个区域里，<unk>的<unk>，<unk>的<unk>，这些<unk>会<unk>。<e>]
#
# [they needed to open up space for somebody else that they thought could come back from whatever they were going through .] => [<s>他们需要<unk>，他们可以在家里<unk>他们的选择。<e>]
#
# [i 've been digging through the literature for the original reference for that number , and i could never find it .] => [<s>我在<unk><unk>搜寻了一些<unk>，我甚至<unk>了<unk>的证据。<e>]
#
# [so we got one of these robots .] => [<s>我们就有了一个机器人。<e>]
#
# [there would be on board a crew of artists , musicians , that would allow the thing to become actually kind of a conscious object that would respond to the moment , and to interact as an entity that was aware , that could communicate .] => [<s>也可以在一个艺术家上<unk>，一个艺术家，让他们能够做一些个性化的动作，通过语言，让人们能够在一起体验，这是个很好的互动。<e>]
#
# [you see the importance of that ] => [<s>你能看到这个重要性<e>]
#
# [or was it as a mother of an autistic child ] => [<s>还是有自闭症的孩子是一个自闭症患者<e>]
#
# [normally , efficiency is crucial because the fuel cost of your engine over its life dwarfs the cost of the engine .] => [<s>通常来说，最重要的是引擎效率的效率在于它的<unk><unk>的能耗。<e>]
#
# [and there was a day about seven years ago : i was planting potatoes , it was the first week of may -- this is new england , when the apple trees are just vibrating with bloom ; they 're just white clouds above .] => [<s>几年前我就想过<unk><unk>--这是个<unk>的<unk>--它们是<unk>的<unk>--它们是<unk>的<unk>--<unk><unk><unk>。<e>]
#
# [and this is how it works .] => [<s>这就是它的工作原理。<e>]
#
# [so the next thing i saw was just blue .] => [<s>接下来，我看到的是一件事。<e>]
#
# [there is a historical archive .] => [<s>我们有一个<unk>的故事。<e>]
#
# [that is , we have to seriously play god , not just change people 's lives , but make the universe , right .] => [<s>这就是我们必须承认，但是我们的生活不是很简单，而是<unk>的，道德的，是改变世界的。<e>]
#
# [there was a character called the third-stage guild navigator , which was a kind of giant , floating fetus-creature that lived in a giant tank with this orange mist of psychedelic spice swirling around him , allowing him to bend space and time .] => [<s>有一个叫<unk>的人叫<unk><unk><unk>的人，他是<unk><unk>的<unk>，<unk><unk>，<unk><unk>，<unk><unk>，<unk><unk>，<unk><unk>。<e>]
#
# [it 's close to about a million right now .] => [<s>现在大概有大约<unk><unk>。<e>]
#
# [the u.s. is tied for 15th in reading , but we 're 23rd in science and 31st in math .] => [<s>美国<unk>了<unk>，但我们在数学和科学领域中<unk>。<e>]
#
# [and this is what a photograph taps into when it makes its own powerful connection to a viewer .] => [<s>这是个让人<unk>的故事，它的<unk>是由这个<unk>的<unk>的。<e>]
#
# [if i choose a different way of moving -- on the right for example -- then i 'll have a different command , different noise , playing through a noisy system , very complicated .] => [<s>如果我把不同的方式放在不同的位置--不同的，不同的<unk>，不同的，不同的<unk><unk>，<unk><unk>。<e>]
#
# [but actually in scientific community there is great debate about what percentage of flu transmission between people is from sneezing and coughing and what percentage is on your hands .] => [<s>但事实上在科学上的争论，人们都知道<unk>和<unk>的<unk>是什么，<unk>和<unk>的区别。<e>]
#
# [we believe it is .] => [<s>我们相信它是这样的。<e>]
#
# [and so the thought that i started with was how do you do this , still within the boundary of the science we know today -- no time for science fair , no time for playing around with things or waiting for the magic battery to show up .] => [<s>所以我想，这就是我们如何在做的事，就是在做什么的时候，你不能说："我们如何在<unk><unk><unk>，<unk>"和"<unk>"和"之间"的区别"和"整合"]
#
# [i think , really , i can 't talk about race without remembering that it is a construct in certain respects , but also that , you know , until we redress the wrongs of the past , we 're going to be turned around .] => [<s>我认为，不，不只<unk>的力量，我想说的是，我们<unk><unk>，但我们必须<unk>，这就是<unk>的<unk>。<e>]
#
# [we had our mothers , our aunts , our cousins , our sisters , and of course , the ever-present media bombarding us with images and words , telling us how to be .] => [<s>我们也有自己的母亲，我们的姐妹，我们的朋友，我们的孩子，我们的<unk>，我们的<unk>，我们的身体和<unk>的朋友们。<e>]
#
# [i read about it . it was in le monde .] => [<s>我读了<unk>。这是在<unk>。<e>]
#
# [which brings me to the final element , which is education .] => [<s>这也是我最后想探讨的，是教育的方式。<e>]
#
# [and that 's where the field is today .] => [<s>而这就是今天的处境。<e>]
#
# [remember , 2001 , we had less than two hours radio contact with the outside world .] => [<s>请记住，我们的孩子们都有一天24小时，并与外界<unk>联系起来。<e>]
#
# [so , when i started riverside school 10 years ago it became a lab , a lab to prototype and refine a design process that could consciously infect the mind with the " i can " bug .] => [<s>当我10年前从伦敦的学生开始研究"<unk>"，开始学习新的机器，并尝试<unk>的基因并将其作为<unk>的染色体。<e>]
#
# [so think about the future — it will be here soon enough .] => [<s>想象一下未来会发生什么，然后再<unk>。<e>]
#
# [and , in fact , to understand it , i eventually had to create a whole new kind of science .] => [<s>事实上，我终于明白，我必须找到新的科学方法<e>]
#
# [so they are well-motivated .] => [<s>所以他们都是<unk>的<e>]
#
# [how would you feel if you were me  you have something extraordinary in your hand , but you are in the middle of nowhere ] => [<s>如果你觉得你在<unk>什么都有，你就会在这一刻<unk>吗<e>]
#
# [and you know how you find out  you look at their eyes .] => [<s>你知道，你看他们的眼睛如何看他们。<e>]
#
# [so we 've now accomplished the objective , which is to get the message from bob to alice without the server being able to read what 's going on .] => [<s>现在我们已经进行了<unk>尝试，也就是<unk><unk>的信息，也不会<unk>信息的<unk>。<e>]
#
# [so that 's actually what i began to do .] => [<s>所以我就开始做了。<e>]
#
# [in the catholic chronology , catholic calendar , at the end of march you will think about st. jerome and his qualities of humility and goodness and his generosity to the poor .] => [<s>在<unk><unk>，<unk><unk><unk>的<unk><unk>，<unk>的人，<unk>和他的朋友们<unk><unk>和<unk>。<e>]
#
# [what is the cost of that battery ] => [<s>那么多的电池呢<e>]
#
# [bacterial cellulose is actually already being used for wound healing , and possibly in the future for biocompatible blood vessels , possibly even replacement bone tissue .] => [<s><unk>已经被用来使用的是，事实上，用<unk><unk>来代替<unk>，而我们可以用<unk>的<unk>来代替<unk>。<e>]
#
# [this is white noise .] => [<s>这是<unk><unk>。<e>]
#
# [this is fairly recent science that has shown that .] => [<s>这是最近的科学发现的。<e>]
# [lucas again , in 1876 , showed us - 1 , 21 digits long , was not prime .] => [<s><unk>年中，<unk>年，我们展示了：英国的<unk>，<unk>，<unk>。<e>]
#
# [but one time it broke down .] => [<s>但它却<unk>了。<e>]
#
# [printing press took a century to be adopted ; the first computers were designed pen-on-paper -- now we use computers .] => [<s><unk>启动了第一个尝试了<unk>电脑程序--我们设计了电脑。<e>]
#
# [but what if this wasn 't the first time ] => [<s>但如果这不是什么呢<e>]
#
# [and on the other side , some african-americans dismissed or ignored homophobia that was indeed real in our community .] => [<s>另一些，有些<unk>的<unk>，也是<unk>的一部分，也是我们大多数人都在<unk>的。<e>]
#
# [this technological revolution is as inspiring and transformational as anything we have ever seen .] => [<s>这种革命的革命和技术革命会开始<unk>。<e>]
#
# [and , you see , this era coincided with my own childhood .] => [<s>你看，我的童年经历了<unk>。<e>]
#
# [and you can 't see this very well on the screen , but arduino -- arduino is an open-source hardware platform .] => [<s>你看不到这个地方，但是这并不是一个很好的例子，是在<unk>，一个<unk>的平台。<e>]
#
# [here i 'm one person talking to you .] => [<s>我这里是一个人跟你说话。<e>]
#
# [she recently returned to dongguan on her own to take a job in a factory that makes construction cranes , temporarily leaving her husband and children back in the village .] => [<s>她最近做了她的工作，她在<unk><unk>了<unk>，并<unk>了她的<unk>，<unk>了<unk><unk>的村庄。<e>]
#
# [what are we missing ] => [<s>我们什么都没有什么呢<e>]
#
# [and it all grew out of one of my colleagues asking me to analyze a bunch of brains of psychopathic killers .] => [<s>我的同事也是我研究过的最多的人的<unk><unk>，我想，他们会有更多的<unk>的<unk>。<e>]
#
# [now maybe cows have a really rich internal mental life and are so smart that they choose not to let us realize it , but we eat them .] => [<s>也许，现在有一个<unk>是很聪明的<unk>，我们的选择是<unk>的，我们就会变得非常自私，直到我们开始<unk>。<e>]
#
# [but it was deeper . it was , how much life is there left ] => [<s>但它是<unk>的，这就是为什么生命的起源<e>]
#
# [so now we 're funding them to the tune of about five or six million dollars to collaborate and bringing them together , and that 's a unique thing in the cancer world , and we know , through that collaboration , it will accelerate outcomes .] => [<s>现在我们来谈谈<unk>基金会的<unk>，我们需要把这两<unk>分成<unk>，并且我们需要一个全新的、音乐的<unk>来<unk>。<e>]
#
# [people who experienced a lot of stress but did not view stress as harmful were no more likely to die .] => [<s>压力压力的压力反应压力反应不是因为压力而不是压力<e>]
#
# [i 'm the president of the journalism & amp ; women symposium , jaws . that 's sharky .] => [<s>我对伊斯兰教的<unk>开始<unk>，但<unk>，<unk>，<unk>。<e>]
#
# [in the eye of a theoretical physicist , the higgs boson is a clever explanation of how some elementary particles gain mass , but it seems a fairly unsatisfactory and incomplete solution .] => [<s>在宇宙中，<unk>是一个<unk>的理论，解释是它的<unk>，但它的<unk>是一个<unk>的概念，但是它的<unk>是一个<unk>的<unk>。<e>]
#
# [but after a very short while , you can see these blue things on the right there begin to take over .] => [<s>但是在<unk>之后，你可以看到这些蓝色的线在这些地方的<unk>。<e>]
#
# [we now have a whole underground marketplace and business ecosystem built around online crime .] => [<s>现在我们看到了一个商业的<unk>，它是由跨国公司建立的，<unk>的网络。<e>]
#
# [language , on the other hand , has an intermediate level of entropy ; it 's neither too rigid , nor is it too random .] => [<s>另一方面，在语言中，有一个<unk>，它的存在，没有任何副作用，<unk>，<unk>。<e>]
#
# [of course , the criminal justice system treats them as common old garden criminals .] => [<s>当然，<unk>系统的<unk>是他们<unk>的<unk>。<e>]
#
# [but how wrong it is .] => [<s>但它如何呢<e>]
#
# [they do distributed practice , so little shots of 40 minutes several days over a period of two weeks .] => [<s>他们<unk><unk>，所以在两天前就有两个星期在<unk>。<e>]
#
# [and it was an incredibly thing , working with the u.n.] => [<s>这是个让人难以置信的<unk>的事情<e>]
#
# [and , for example , wolfram alpha and mathematica are actually now full of algorithms that we discovered by searching the computational universe .] => [<s>举例来说，wolframalpha<unk>是我们发现它可以计算出<unk>的<unk>的<unk><e>]
#
# [] => [<s>（鼓掌）<e>]
#
# [in conflicts from the crimean peninsula to latin america , from europe to the united states , hackers are a force for social , political and military influence .] => [<s>从<unk>年到美国<unk>的政治<unk>的政治<unk>，政治和美国的政治制度，<unk>和其他的政治制度。<e>]
#
# [where 's the sound coming from ] => [<s>声音从哪里来<e>]
#
# [but when i needed it , it was a godsend .] => [<s>但是，当我需要它，它是一个<unk>。<e>]
#
# [i don 't know if you realize this , but 90 percent of the patients on the transplant list are actually waiting for a kidney .] => [<s>我不知道你们在意识中所做的，在<unk><unk>的病人身上，只有30%的人在等着<unk>。<e>]
#
# [he 's in his 80s and he lives in florida . he 's a tremendous guy .] => [<s>他在<unk>岁的时候他住在一个非常<unk>的人<e>]
#
# [sir david attenborough , he 's come over .] => [<s><unk><unk>，他是<unk>。<e>]
#
# [and if we look to the future , it 's an unsustainable diet .] => [<s>如果我们想了解未来，那是个<unk>的未来。<e>]
#
# [and you have refining and delivery of that crude oil as what we call petrol or gasoline .] => [<s>而且你还可以用同样的材料来解决"<unk>"或"<unk>"。<e>]
#
# [okay . so here 's the read on it .] => [<s>好，所以，这是在阅读。<e>]
#
# [whenever there is an election , it seems like something always goes wrong , someone tries to cheat , or something goes accidentally awry -- a ballot box goes missing here , chads are left hanging over here .] => [<s>在某个时候，总有一个会发生在<unk>中，比如<unk>，<unk>，<unk>，<unk>，<unk><unk>，或者是一些<unk>的<unk>，然后试着找出一个<unk>的<unk>。<e>]
#
# [and this is only one of the conditions that 's out there .] => [<s>而这是在整个唯一条件下的。<e>]
#
# [so i ran out in the freezing cold , and i photographed every single person that i knew that i could get to in february of about two years ago .] => [<s>于是我<unk><unk>，在<unk><unk>，我知道了几个月前我在<unk>的时候都有自己的经历。<e>]
#
# [secondly , make it clear from the beginning that either you have no money at all or that you would rather spend money with your attorney fighting the troll than actually giving them the money .] => [<s>第二，从你的钱开始，你就不会有钱，你不需要钱来赚钱，然后在<unk>里，<unk>。<e>]
#
# [so , she wears the disk , and reads the data off the sectors of the disk , and the computer starts up ; it sort of boots up , really .] => [<s>她把<unk><unk>到<unk>，<unk>，<unk>，<unk>，<unk>，然后<unk>。<e>]
#
# [here 's three values .] => [<s>这是三种价值观。<e>]
#
# [i made up pre-death .] => [<s>我做了<unk>。<e>]
#
# [well , hackers in the back row replied , " then stop arresting us . "] => [<s>好吧，<unk>的<unk>，"请把它<unk>。"<e>]
#
# [i said , " girls , well , well , you never know unless you ask . "] => [<s>我说，"好吧，你从来都不知道，你是最好的。"<e>]
#
# [and we also know that the world has changed in other ways , that since 1960 there are one-third as many new countries that exist as independent entities on the planet .] => [<s>我们也知道，世界上的其他很多国家已经存在了很多，在过去的十年里，在全球范围内，在发展中国家，我们的孩子们就已经存在了。<e>]
#
# [and rightly so , in many cases .] => [<s>很多人都在<unk><e>]
#
# [and then we bring that into software , and we reassemble it and we tell you what the story is .] => [<s>然后我们用<unk>，我们把它<unk>给你，你会说："这是个<unk>。"<e>]
#
# [it was only 200 years ago that we had the advent of the industrial revolution .] => [<s>只有在工业革命前我们<unk>了200年。<e>]
#
# [but i really like my tea sweet . "] => [<s>但我<unk>我的<unk>。"<e>]
#
# [we do the opposite of them .] => [<s>我们做了很多不同的事情。<e>]
#
# [it 's a material hardener and synthetic estrogen that 's found in the lining of canned foods and some plastics .] => [<s>它是一种<unk>塑料和<unk>塑料制成的蛋白质和塑料碎片<e>]
#
# [it turns out that something more than 94 percent of life on earth is aquatic .] => [<s>地球上的<unk><unk>是地球上最自然的<unk><e>]
#
# [in order to run in the general election , you must do extremely well in the lester election .] => [<s>为了选举<unk>，你必须在选举<unk>。<e>]
#
# [if you put a five year-old child 's dexterity against the best robots of today , the answer is simple : the child wins easily .] => [<s>如果你有一个孩子<unk>的孩子的建议，那就是，最好的数字是：<unk>的孩子，<unk>，<unk>。<e>]
#
# [the simplest heat engine , or hot air engine , of all time would be this -- take a box , a steel canister , with a piston .] => [<s>最简单的引擎，引擎<unk>，<unk>，<unk>，<unk>，<unk>，<unk>。<e>]
#
# [but the reason i could come here is because of that .] => [<s>但我之所以这么说是因为这里的原因。<e>]
#
# [and of course , most of you don 't support the insurgency ; you don 't support killing americans ; you don 't support the terrorists .] => [<s>当然，大部分人都不会<unk>，但是你不能支持<unk>，也不是为了支持<unk>。<e>]
#
# [what 's happening now , in this field called biomimicry , is that people are beginning to remember that organisms , other organisms , the rest of the natural world , are doing things very similar to what we need to do .] => [<s>现在发生的事情就是，生物多样性的生物多样性开始了解到，这些生物的生物是我们可以做的，实际上，我们也需要了解到这些细菌的生命。<e>]
#
# [but it was also the largest city that had ever been built .] => [<s>但它也是城市中最大的<unk>。<e>]
#
# [it started out with an article in red herring .] => [<s>它在<unk><unk><unk>。<e>]
#
# [so to start , i want to introduce some characters from a book i made for teenagers .] => [<s>首先，我想从我的一些作品中学到很多年轻的女孩儿的<unk><e>]
# [it turns out people think when they win the lottery their lives are going to be amazing .] => [<s>当人们觉得他们会<unk>的时候会觉得这真是太棒了<e>]
#
# [and we now have 1,400 volunteers on our roster .] => [<s>在<unk>我们有了<unk>我们<unk>的<unk><e>]
#
# [you might take states like iowa and ohio -- two very important political states , by the way -- those two governors , and they would say , we 're going to lead the nation in producing the wind turbines and the wind energy .] => [<s>你可以<unk><unk>－－－－－－－－－－－－－<unk>的<unk>会有2个<unk>－－－－－－这可能是<unk>的<unk><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk><unk>]
#
# [it 's that you can see the world as it isn 't .] => [<s>这就是你能看到世界的世界。<e>]
#
# [if you want to talk about it , you know , i will listen to you through .] => [<s>如果你想听，我会倾听你们<e>]
#
# [there 's the nest entrance , there 's a pencil for scale .] => [<s>这是<unk>的，有一个<unk>，<e>]
#
# [today , the depletion of ocean fisheries is so significant that effectively it is effecting the ability of the poor , the artisanal fisher folk and those who fish for their own livelihoods , to feed their families .] => [<s>现在，海洋<unk>的主要<unk>是非常重要的，这些是<unk>的<unk>，他们的<unk>，以及<unk>的<unk>，以及他们的<unk>能力，以及他们的<unk>的<unk>。<e>]
#
# [so , that clearly wasn 't going to work .] => [<s>显然，这工作的工作方式没有<unk>。<e>]
#
# [and the government is responsive . so for instance , when it was reported on this website that 800 students were at risk because school repairs had stalled due to corruption , the department of education in the philippines took swift action .] => [<s>还有一个问题比如，<unk><unk>，当我在<unk>年发现的时候，这个问题是在<unk><unk><unk>的学生因为<unk>的<unk><unk><unk><unk><unk>的<unk>。<e>]
#
# [indeed , rensink 's subjects took only a little bit more than a second to press the button .] => [<s>的确，<unk><unk><unk>了一个小版本的<unk>。<e>]
#
# [so , this is an exhibition pavilion where there is absolutely nothing to see and nothing to do .] => [<s>这个作品是一个<unk>的地方，而不需要什么东西来<unk>。<e>]
#
# [and so does your [ bleep ] . these days , with a hair-free back , well-groomed shoulders and an extra optical inch on my [ bleep ] , well , let 's just say life has gotten pretty darn cozy .] => [<s>那么你就会看到这些点"<unk>"，<unk><unk>的<unk>，<unk><unk>的<unk>，一个<unk>的<unk>，一个<unk>的<unk>。<e>]
#
# [the incremental advances have added up to something which is not incremental anymore .] => [<s><unk>已经解决了这个问题，它的<unk>已经<unk>了。<e>]
#
# [we had someone talk about measuring emotions and getting machines to figure out what , to keep us from acting crazy . right ] => [<s>我们有了各种各样的尝试去尝试读出情绪的行为--从心理的角度来思考，我们想出什么<e>]
#
# [put in other language , it means you have to use your skills and talents and abilities to help the organization achieve its strategic financial goals and do that by working effectively with others inside of the organization and outside .] => [<s>换个语言，你就能<unk>，你的能力和能力，和其他的团队，需要<unk>的能力，以及其他的团队在工作中的<unk>和技能。<e>]
#
# [so this was an opportunity . if they were asking me whether i loved them or not , then i mustn 't love them , which led me to the miracle of thought that i thought they wanted me to get to .] => [<s>所以这是个好消息。当我问他们，这是我唯一的东西，我想，他们都不会去做这些事情，因为我想我也不会想他们的梦想，我也不会相信我。<e>]
#
# [nobody is starving anymore , thank god .] => [<s>没有人曾经<unk>过，上帝。<e>]
#
# [another thing i do is i invent stuff .] => [<s>另外一件事我做的是发明了<unk>。<e>]
#
# [and -- they don 't throw it at each other , but this is a fundamental part of being playful .] => [<s>而且他们并不会<unk>但这是个很难的<unk><e>]
#
# [the people in the modern world , in the secular world , who are interested in matters of the spirit , in matters of the mind , in higher soul-like concerns , tend to be isolated individuals .] => [<s>全世界的人民，在世俗的社会中，人们的思维方式是在<unk>的，但在<unk>的道德上，<unk>的重要因素是至关重要的。<e>]
#
# [you believe a proposition , p , and i don 't .] => [<s>你相信<unk>，<unk>，我是说，<e>]
#
# [i didn 't realize that it would become the most amazing journey of my life .] => [<s>我意识到这并不是最美妙的生活方式。<e>]
#
# [but he was right , it was a stupid idea .] => [<s>但他是个<unk>，他是个<unk>的想法<e>]
#
# [this is technology , entertainment , design and there 's a dairy cow .] => [<s>这是科技，娱乐和设计，<unk>是<unk>。<e>]
#
# [this discovery changed everything about our sense of these cliffs and what to do with them .] => [<s>这个改变的发现就是这些东西的<unk>和我们所做的事情。<e>]
#
# [and we don 't invest in what 's invisible to us .] => [<s>我们不是在不知道我们在找什么<e>]
#
# [it should be built in to all the systems we use .] => [<s>我们应该把所有系统都放在一起。<e>]
#
# [and torture 's a terrible enough thing as it is , but when it 's done by your hero , that just breaks you in so many ways .] => [<s><unk>的事情也很可怕但当你<unk>的时候，它就会<unk>你的<unk><e>]
#
# [okay  we cannot reduce animal numbers to rest it more without causing desertification and climate change .] => [<s>我们不能再<unk><unk>的动物，而不是<unk>细菌的<unk>，而不是<unk>。<e>]
#
# [this blue neuron is connected with the locomotor center , and what this constellation of synaptic contacts means is that the brain is reconnected with the locomotor center with only one relay neuron .] => [<s>我的<unk>与<unk>连接的神经细胞连接在一起，这是个<unk><unk>的<unk>，而这些网络会变成一个<unk>的<unk><unk>。<e>]
#
# [the corals are doing better here . lots of small fish .] => [<s>珊瑚的空气很好。它们也有很多<unk>。<e>]
#
# [this is something you leaked a few years ago .] => [<s>你几年前就有一些<unk><e>]
#
# [well , there 's lots to talk about , but i think i 'm just going to play to start off .] => [<s>好吧，我想谈谈我现在要谈的，但我想谈谈<unk>。<e>]
#
# [i don 't mean you shouldn 't go to college , but not everybody needs to go and not everybody needs to go now .] => [<s>我不是说你应该不应当去想，而是人人都要<unk>，但是现在，每个人都想<unk>。<e>]
#
# [two stage rockets , rockets with video cameras on them , on-board computers logging their flights , rocket gliders that fly back to earth .] => [<s>火箭火箭<unk>火箭<unk>，火箭<unk>，火箭<unk>，<unk>，<unk><unk>，我们可以用<unk>飞行的速度飞行。<e>]
#
# [i found no flaw .] => [<s>我没有<unk>。<e>]
#
# [let 's take something like water .] => [<s>让我们<unk>水。<e>]
#
# [it 's not just my group ; there 's maybe 30 groups worldwide doing this .] => [<s>我的工作是没有人可以<unk>，也是全球30％的会议。<e>]
#
# [napoleon got a few things wrong ; he got this one absolutely right .] => [<s><unk>有一点点的<unk>。他有一个<unk>。<e>]
#
# [that 's kind of the way you communicate .] => [<s>这就是你和他人的方式交流。<e>]
#
# [and can you see that this increase took place without life getting longer and without adding children ] => [<s>你能把这些海量的信息都<unk>在一起，而不是<unk>的寿命，<e>]
#
# [what is the appropriate new metaphor for aging ] => [<s>那么我们对<unk>的进化有什么反应<e>]
#
# [and one of our litigation strategies was actually to send me into the home of these clients with these large glass bottles .] => [<s>我们的一个<unk>的<unk>是我把这些<unk>的<unk><unk>给了我这个<unk>的<unk>。<e>]
#
# [and i thought , well this is going to be child 's play .] => [<s>我想，这是个孩子的<unk>。<e>]
#
# [and i want to tell you a quote from ralph emerson that one of my colleagues , you know , put on my wall in my office , and it says , " do not go where the path may lead .] => [<s>我想告诉你我的同事<unk>在我的办公室里<unk><unk>，我的同事在说，"你知道吗，在<unk>的时候，你会不会对它进行<unk>。<e>]
#
# [and she said , " what would i miss ] => [<s>她说："我什么都<unk>了"<e>]
#
# [one gram 's 80,000 individuals , 80,000 individuals are good enough to control one acre , 4,000 square meters , of a strawberry plot against spider mites for the whole season of almost one year .] => [<s>一个<unk>是<unk><unk>的<unk><unk>，在<unk>，<unk><unk><unk><unk><unk><unk>的<unk><unk><unk>，我们可以在<unk>内<unk>。<e>]
#
# [the first two and a half percent of our population are our innovators .] => [<s><unk>的一半是我们的祖先<e>]
#
# [i think this comes from what a teacher colleague of mine calls " the bulimic method of education . "] => [<s>我想，我的同事老师说，"我的<unk>是一个<unk>的老师。"<e>]
#
# [there are starfish that can make light .] => [<s><unk>可以说它<unk><unk><e>]
#
# [so when you start to look at cyber from this perspective , starts to seem kind of exciting .] => [<s>所以当你开始从<unk>开始的时候，就会开始思考<e>]
#
# [so , as you see , people care about harm and care issues .] => [<s>所以，你看，人们关心和关心的问题。<e>]
#
# [the other interesting thing for us -- we like sensors -- is this idea that you could have an on-ramp for the internet of things .] => [<s>其他的其他方法是像我们一样——但是我们喜欢的是一个<unk>的网络，你就知道每个人都有<unk>。<e>]
#
# [and i want to look at sweden and the united states .] => [<s>我想再看看瑞典和瑞典<e>]
#
# [effectively you would have something like this .] => [<s>你就会这样做<e>]
#
# [this is odysseus as an old man who wants nothing more than to retire in a sunny villa with his wife penelope outside of ithaca -- the other one .] => [<s><unk><unk><unk><unk><unk>的<unk>，而不是<unk><unk>的<unk>，在一个<unk>的<unk>里。<e>]
#
# [and then i 'm going to attempt onscreen animation here .] => [<s>然后我就试着去尝试<unk>动画<e>]
#
# [then he starts going up , and the next thing i hear is , " i 'm half-way up . it 's like climbing stairs . i 'm going up 60 degrees .] => [<s>然后他就开始<unk>了。我的<unk>就在我的脚上，我有<unk>，我<unk>了。<e>]
# [are the basics of writing learning how to sharpen a quill ] => [<s>这些学习如何通过<unk>学习的方式学习<e>]
#
# [of course there 's health consequences to this , scary ones , besides the waist .] => [<s>当然，负面的影响因素都很可怕，当然，<unk>。<e>]
#
# [and that 's where i think organizations like ted , like the extreme ice survey can have a terrific impact on human perception and bring us along .] => [<s>而且我认为，像这样的组织就像这样，我们可以通过这些数据来传播，像我们这样对待人类的<unk>和<unk>的能力。<e>]
#
# [it 's in its early stages , and it 's crude by some measures , but in fact , 20 years ago , we were at nothing .] => [<s>它在早期的早期，它在<unk>，而且它是20世纪早期，但它是我们所知道的。<e>]
#
# [and that lower photo , that 's a bird colony that has been boomed .] => [<s>而<unk>，这是在<unk>中，<e>]
#
# [from the rulebook : nomenclature is a tool .] => [<s>从<unk><unk>："<unk>"是一个工具。<e>]
#
# [and they will start to buy electric cars .] => [<s>他们开始买汽车的<unk>。<e>]
#
# [and the gems are always the outermost aspects of our interviewee 's personality .] => [<s>那些<unk>的<unk>都是<unk>的<unk>的<unk><e>]
#
# [i can tell you he won 't call back . it 's a vibe i share .] => [<s>我可以告诉你，他不可能是我的<unk><unk>。<e>]
#
# [that means the power of others things is rising .] => [<s>这意味着，<unk>的力量也会被<unk>。<e>]
#
# [i 'm excited to be here to speak about vets , because i didn 't join the army because i wanted to go to war .] => [<s>我之所以参军是因为我想参军因为我没有军队，因为他们不想<unk>战争。<e>]
#
# [this studies the circuitry in two people 's brains that activates while they interact .] => [<s>这个实验老鼠的大脑实际上在老鼠身上植入了这些老鼠。<e>]
#
# [he wanted to test out the question of , where is it that patients should recover from heart attacks ] => [<s>他想知道的是，我们应该在测试病人的情况下，谁能得到什么<e>]
#
# [they live life knowing they live it against the law .] => [<s>他们生活生活在法律生活中的作用<e>]
#
# [and the breast cancer campaign -- again , this is not a competition .] => [<s>乳腺癌的竞争——这并不是一个竞争。<e>]
#
# [the second issue is a nuance of the first .] => [<s>第二个问题是关于<unk>的。<e>]
#
# [this is an illusion .] => [<s>这是个幻觉<e>]
#
# [the folks who i described earlier got proper preparation in teaching , not in any college or university , but by virtue of just being in the same spaces of those who engage .] => [<s>我之前讲到过的那些学术<unk>人士都在大学里学习，但在<unk>，也不仅仅局限于<unk>，也是关于在社区中的每一个人，都是基于他们自己的。<e>]
#
# [rape is not barbaric , but the law , he said , was barbaric .] => [<s><unk>不是<unk>，不是<unk>，而是<unk>，<e>]
#
# [work out the implications .] => [<s>这工作原理是什么<e>]
#
# [they understand that theater and performance can happen anywhere .] => [<s>他们认为这可以从任何地方发生，然后选择<unk>。<e>]
#
# [so here 's the metaphor i 'm offering today .] => [<s>我今天要讲的就是这个<e>]
#
# [" the matrix " is a movie that is all about glamour .] => [<s>"<unk>"是"<unk>"的一部分。<e>]
#
# [diver 2 : hoo ] => [<s><unk>:2<e>]
#
# [the earth is neither flat nor round .] => [<s>地球是<unk>的，也不是<unk>。<e>]
#
# [well , you need about 75 pounds of it .] => [<s>嗯，你应该把它的<unk><unk>。<e>]
#
# [the audience is led to make assumptions or elaborations that are perfectly reasonable , but do not , in fact , match what is being done in front of them .] => [<s>"内在"其实就是为了测试<unk>，<unk><unk>，但信仰的<unk>，都是<unk>的。<e>]
#
# [i know that you are angry , and i know that you would almost wish to have the opportunity to enter now into activities of revenge . but , " he said , " what i really want you to know is that i know how you feel .] => [<s>我知道你是知道什么是人们，我想知道你是谁，我想知道你是什么，我想告诉大家，我知道这是个<unk>的问题。我认为这是个<unk>的地方。<e>]
#
# [this information used to be private .] => [<s>这个信息可以被<unk>。<e>]
#
# [and so we 've done this actually on eight subjects now , and we 're just getting all the data together , so hopefully we 'll have something to say about it meaningfully .] => [<s>所以我们在这个过程中收集了所有数据，所以我们现在就把数据<unk>了，所以我们可以把它<unk>一些。<e>]
#
# [they called me two weeks later , they 're like , oh , yeah , you can come now . and i told them to stuff it .] => [<s>他们两周后，我把它们<unk>，然后，你再告诉他们，你知道，我想。<e>]
#
# [so we paid attention to a particular grammatical rule , past-tense conjugation .] => [<s>我们<unk>了<unk>的<unk><unk>，<unk><unk>。<e>]
#
# [a father and daughter separated from a bicycle by a mysterious wall .] => [<s>一个女儿<unk>的<unk>，把它<unk><unk>。<e>]
#
# [so at 18 , i was bonded off to prison in nigeria .] => [<s>所以，在<unk>的时候，我在<unk>监狱服刑了。<e>]
#
# [but the promise of neuroscience has led to some really high expectations and some overblown , unproven claims .] => [<s>但<unk>的<unk>是<unk>的，包括<unk>的人，以及<unk>的<unk>。<e>]
#
# [outcomes may depend on various parameters .] => [<s>除了不同的<unk>在不同程度上<e>]
#
# [unfortunately , though , the site was separated from the river by mclean boulevard so i suggested , " let 's reroute mclean , " and that gave birth instantly to friends of mclean boulevard .] => [<s>可惜的是，我的<unk>被关进了<unk>，<unk><unk><unk>，我的朋友<unk><unk><unk>，<unk><unk>。<e>]
#
# [and there 's just about every element of the periodic table in seawater .] => [<s>它是所有深海里的<unk>的<unk>。<e>]
#
# [on the scale of decades , in our lifetimes , we 're going to see a lot of damage to coral reefs .] => [<s>在我们的珊瑚礁的水平，我们就会发现很多珊瑚礁污染。<e>]
#
# [but it actually turns out to be pretty hard to turn pages , and the volume isn 't there .] => [<s>但是，实际上，我们还没有<unk>，其实也是<unk>的。<e>]
#
# [and we found america 's longest-lived population among the seventh-day adventists concentrated in and around loma linda , california .] => [<s>我们发现在美国，<unk><unk>的地方<unk><unk><unk><unk><unk><unk><unk>。<e>]
#
# [zk : now , it 's important to understand what the unexpected properties are .] => [<s><unk>：对这些问题的重要性是了解到的一些重要的组成部分<e>]
#
# [giveindia is for a whole country .] => [<s><unk>是一个国家的<unk>。<e>]
#
# [cloning was science fiction . it had not happened .] => [<s><unk>是<unk>。不是小说。<e>]
#
# [a song is running through your head -- you sing it into the thing : ok , you tap , " done " and it will find out the song and play it for you .] => [<s><unk>首歌是一首曲子，然后<unk><unk>，你需要<unk>，你<unk>，<unk><unk>。<e>]
#
# [today , the united states and china are the two leading economies in the world .] => [<s>今天，美国和中国的<unk>是个<unk>的。<e>]
#
# ...
#
# [now , i can extend this circular magnet , and make whatever track i want .] => [<s>现在，我可以把这个<unk>的<unk><unk>，我可以把它<unk><unk>。<e>]
#
# [military power is important .] => [<s>军队是重要的。<e>]
#
# [well , not quite , not quite perfect -- you see , in intergalactic space -- intergalactic space is completely dark , pitch dark .] => [<s>但是，不是——————————————————————————————————————————————]
#
# [we 're not feeling it . we 're thinking beauty is in the limbic system -- if that 's not an outmoded idea .] => [<s>我们并不喜欢这个，我们认为我们的基因并不<unk>，我们认为它是<unk>的。<e>]
#
# [this won 't hurt . okay .] => [<s>这不会<unk>。<e>]
#
# [could we use , let 's say , pharmacological drugs to activate or inactivate brain cells ] => [<s>我们可以用<unk>的方法，比如<unk><unk><unk><unk><unk>的药物<e>]
#
# [would you like to hear me play ] => [<s>我想听你们吗<e>]
#
# [he was now dr. carlock in the movie .] => [<s>他现在在<unk><unk>了<unk>。<e>]
#
# [now give us a punishment . okay .] => [<s>现在是个好笑话。好的。<e>]
#
# [the thought that you wouldn 't want to transfer electric power wirelessly , no one ever thought of that .] => [<s>我们想把能源的方式不会<unk>，没有任何形式的形式。<e>]
#
# [let 's look at some 2006 numbers . kenya : over 60 percent . nigeria : over 40 percent .] => [<s>让我们看看肯尼亚的一些：90年代，9千的<unk>：90％。<e>]
#
# [they are in issues that i 'm passionate about : gun control and drug policy .] => [<s>我是他们正在研究的：<unk>和<unk>。<e>]
#
# [now , of course , that idea has brought us all of the computer technology we have today and so on .] => [<s>当然，现在，我们的技术已经把我们的所有<unk>都<unk>了。<e>]
#
# [having chosen a particular path , i can hold my hand on that path as infinitely many different joint configurations .] => [<s><unk><unk>，我可以做出一个<unk>的<unk>，我可以把它的<unk><unk>。<e>]
#
# [now , am i saying that there are dumb people working here ] => [<s>我是说，谁在这里没有<unk>呢<e>]
#
# [the old man only said one more thing : " this is the end . "] => [<s><unk>的人才是说，"人知道这个故事。"<e>]
#
# [those stones have been smuggled as three prayer beads of 33 stones each through arabia into andalusia in spain , where they 're safe for 200 years .] => [<s><unk><unk>被<unk>为<unk><unk><unk><unk><unk><unk><unk>的<unk><unk><unk><e>]
#
# [so let 's abandon the paradigm of let 's search for the coolest chemistry and then hopefully we 'll chase down the cost curve by just making lots and lots of product .] => [<s>让我们来研究一下我们的<unk>计划，我们会把<unk>的<unk><unk>，然后再把它<unk>，让我们的研究提供<unk>的<unk>。<e>]
#
# [so , we know it works . what would the content be of these international standards ] => [<s>我们都知道了。<unk>的问题是，他们是怎样应对全球性的<e>]
#
# [i had the opportunity to have a discussion with president mbeki , and one of the things that we talked about is , what is it that 's keeping this connectivity goal from moving ahead faster ] => [<s>我有一个<unk>和一个<unk>的演讲来结束我的演讲，这个想法是我们对这个星球的<unk>和经济发展的<unk><e>]
#
# [very soon , the same systems that we use today to bring music and entertainment and gps information into our vehicles are going to be used to create a smart vehicle network .] => [<s>不久，我们的想法是，使用网络和网络，我们使用的是一个网络的系统，我们将他们与网络<unk>的<unk><unk>一起<unk>。<e>]
# [we could have been done by lunch here .] => [<s>我们可以在<unk>做这样的事情。<e>]
#
# [think about vibration control or great sneakers , for example .] => [<s>想想<unk><unk>的，<unk>的，<unk>的<e>]
#
# [it 's because of air quality .] => [<s>因为空气温度很高。<e>]
#
# [" hail to the gods of america . "] => [<s>"<unk>，<unk>。"<e>]
#
# [and the size of the bubble is the population .] => [<s>气泡的大小代表着人口的大小。<e>]
#
# [and she wanted to study the talmud .] => [<s>她想研究<unk><unk><e>]
#
# [now , it actually gets better than this .] => [<s>现在，这个数字还不止这些。<e>]
#
# [perhaps this is just me , maybe you .] => [<s>也许这是我也许你们<e>]
#
# [the question of what i wanted to do was filled in very quickly with saying , i guess i 'll be an army officer .] => [<s>我想做的是想说一下，我想我是个<unk>的人。<e>]
#
# [the elephant just decayed and they just got the tusks .] => [<s>大象<unk><unk>，<unk><unk>，<e>]
#
# [and we keep getting wells that are farther away from the ground .] => [<s>我们还需要从地面上<unk>。<e>]
#
# [we see these magnificent star nurseries , where nature has somehow arranged for just the right numbers and just the right sizes of stars to be born for life to arise .] => [<s>我们发现了一些<unk>的图像，就是大脑的<unk>，而这正是<unk>的<unk>，而你的大脑会逐渐<unk>。<e>]
#
# [what will happen if the billion people today who live on less than one dollar a day rise to three billion in the next 30 years ] => [<s>今天的平均每个人每天都会有30亿的<unk>在30年内会有30亿人口<e>]
#
# [when i imagine my life , what my life would have been like without the educational opportunities that i had , it makes me wonder .] => [<s>当我生活在我生命中的人生历程中，我的人生经历就会被<unk>，我的感觉就像我自己的<unk>。<e>]
#
# [the fire is still there . how do you say it  [ unclear ] .] => [<s><unk>也没有。<e>]
#
# [and it turns out that manhattan had 55 different ecosystem types .] => [<s>结果是，曼哈顿<unk>生态系统有着不同的生态系统。<e>]
#
# [and we know why , right ] => [<s>我们都知道为什么，对吧<e>]
#
# [so in space , the earth is very small .] => [<s>所以在地球上，小的空间都是如此。<e>]
#
# [the technology was there .] => [<s>科技正在发生<e>]
#
# [she knew she would have to marry that old man , and she was 14 .] => [<s>她知道她一定要<unk>，她<unk>了。<e>]
#
# [the way we tend to use resources is we extract them , we turn them into short-life products and then dispose of them .] => [<s>我们使用的方法是使用<unk>，我们把它们<unk>，我们把它们<unk><unk>。<e>]
#
# [and by the way , they don 't read english anyway , so they are here just for you to know that the correct target is shifting position .] => [<s>顺便说一下，他们没有<unk>，你知道，这只是<unk>的<unk>而已。<e>]
#
# [it 's actually strength -- it 's power .] => [<s>它是<unk>力量，这是种力量<e>]
#
# [why  i 'm not an explorer in the traditional sense .] => [<s>为什么我不喜欢这个传统的建筑<e>]
#
# [it does not form a wall or an obstruction in the city , and light permeates everywhere .] => [<s>它没有发生在<unk>或<unk>或<unk>的地方。<e>]
#
# [now , just think of the early 1960 's in china .] => [<s>现在，在1960年早期的中国才会是<unk>。<e>]
#
# [they lack nutrients , and diarrhea dehydrates them .] => [<s>它们<unk><unk>，<unk><unk>。<e>]
#
# [so if we want to make cells happy outside our bodies , we need to become cell architects .] => [<s>所以如果我们想让我们身体直立行走，我们就能在一个<unk>的环境里。<e>]
#
# [to her girlfriends she said that .] => [<s>她对她说过这是她的<unk>。<e>]
#
# [this is what happens .] => [<s>这就是发生了的事。<e>]
#
# [thank you .] => [<s>谢谢。<e>]
#
# [we can influence behavior .] => [<s>我们可以影响到行为。<e>]
#
# [i 'm seeing too many of these smart kids who haven 't learned basic things , like how to be on time .] => [<s>我很喜欢那些没有<unk>的人在做<unk>的事情，来学习如何<unk>。<e>]
#
# [a simple act , in 1987 , of the most famous woman in the world , the princess of wales , touching an hiv / aids infected baby did a great deal , especially in europe , to stop that .] => [<s>一个很简单的例子就是，从<unk>年到1970年，<unk>的<unk><unk>的<unk>，<unk>的，<unk>的，<unk>的，<unk>的中国人的<unk>。<e>]
#
# [and so we spent a summer looking at different play-doh recipes .] => [<s>我们花了很多不同的<unk>来做不同的事情。<e>]
#
# [so the limbic system is right deep inside the brain , and it 's involved in things like emotion processing and reward processing . it gives you the rewarding feeling out of doing fun things , including taking risks .] => [<s><unk>是<unk>的。大脑中的活动都是<unk>的。<unk>的感觉，你就会发现，<unk>，<unk>，<unk>，<unk>，<unk>，<unk>。<e>]
#
# [if we built a 20-story building out of cement and concrete , the process would result in the manufacturing of that cement and 1,200 tonnes of carbon dioxide .] => [<s>如果我们做出一个<unk>的<unk>，加上<unk>的二氧化碳，在<unk>和<unk>的二氧化碳排放量的排放量。<e>]
#
# [thank you . thank you very much .] => [<s>谢谢。非常感谢。<e>]
#
# [and now , it 's like telling your dog to fly lower , if you have such a dog . so , i can press a button and manipulate it rather easily .] => [<s>现在，狗也跟你的狗一样<unk>，所以你可以把它<unk>，我们的狗也很不一样。<e>]
#
# [and i followed this guy everywhere until i had him in the room , and i read him one of my pieces , and you know what he told me ] => [<s>我在那里做了这个项目，他告诉我，他有没有<unk>我的<unk>，或者是什么样子，你会问我<e>]
#
# [you don 't see it , make no reaction ] => [<s>你看不到它，不是吗<e>]
#
# [we tend to , all of us -- even those of us who work in marketing -- to think of value in two ways .] => [<s>我们都认为我们都是最重要的----------------------------------------]
#
# [so back in abidjan , i was given a chance to lead a workshop with local cartoonists there and i thought , yes , in a context like this , cartoons can really be used as weapons against the other side .] => [<s>所以在我<unk>的时候，我可以在一个<unk>的<unk><unk><unk><unk><unk>，<unk><unk>，<unk><unk>，和我们一起，一个<unk>的故事。<e>]
#
# [but this is now this strange concoction of high calories .] => [<s>但是现在这是在<unk>中，<unk>了<unk>。<e>]
#
# [but this one is -- the bible says that you cannot touch women during certain times of the month , and more than that , you cannot sit on a seat where a menstruating woman has sat .] => [<s>但是这个说，<unk>，你不可能在<unk>上说<unk>语，因为你知道，在<unk>的女人，你可以<unk><unk>。<e>]
#
# [life is temptation . it 's all about yielding , resisting , yes , no , now , later , impulsive , reflective , present focus and future focus .] => [<s>生命的<unk>，都<unk>，<unk>，<unk>，<unk>，<unk>，<unk>，<unk>，<unk>，<unk>，<unk>，<unk>。<e>]
#
# [someone else bought it and died .] => [<s>有人<unk>了它。<e>]
#
# [i tell people it involves creating poetry that doesn 't just want to sit on paper , that something about it demands it be heard out loud or witnessed in person .] => [<s>我告诉大家，大多数人都喜欢<unk><unk>，而不是<unk><unk>，也可以<unk>。<e>]
#
# [ak : a little faster . and much more easy , much more natural .] => [<s><unk>：更容易做的更快，更容易。<e>]
#
# [and most troubling of all is that only 20 percent of syrian refugee children are in school in lebanon .] => [<s>而这些<unk>的唯一的女性是被<unk>为难民营所提供的。<e>]
#
# [and then it is 40 feet deep .] => [<s>而且它是40英尺的地方。<e>]
#
# [that profit is that small difference between the price and the cost it takes to produce whatever solution business has created to whatever problem they 're trying to solve .] => [<s>而这正是<unk>所做的，就是把钱花在<unk>上，同时也需要解决的问题，并解决了<unk>问题，以及其他很多问题。<e>]
#
# [this is very unusual for caves .] => [<s>这不是很<unk>的洞穴<e>]
#
# [and then we have silk , thai silk .] => [<s>然后还有<unk>，非常<unk>。<e>]
#
# [so it 's really interesting , and it makes sense in a way , that they 're still young , so why would they be getting diseases of aging until their old ] => [<s>所以这非常有趣，以至于它们看起来很奇怪，为什么它们会在不断的时间内死去，为什么呢<e>]
#
# [in 2007 , i took my work beyond walls and onto the carroças , as a new urban support for my message .] => [<s>在2007年，我在我的车库里工作，我的<unk>和<unk><unk>了一个新的<unk>。<e>]
#
# [no sensible reform , and we cannot afford a world , a future , with no sensible reform .] => [<s>没有<unk>，我们就不会有<unk>，但我们的社会是没有一个好的社会。<e>]
#
# [hard choices seem to be occasions for agonizing , hand-wringing , the gnashing of teeth .] => [<s>选择<unk>的<unk>，<unk>的<unk>，<unk>的<unk>。<e>]
#
# [what really changed after the ouster of mubarak wasn 't that life got easier .] => [<s>什么<unk>年之后，<unk>改变了<unk>的生活，这也改变了<unk>。<e>]
#
# [that 's really my thinking .] => [<s>这真的是我思考的问题。<e>]
#
# [even in north korea , i was an f student .] => [<s>甚至在<unk>，我是个<unk>的<unk>。<e>]
#
# [you are the individuals you are , and you have this kind of core .] => [<s>你是一个人，你就会得到这个结果。<e>]
#
# [now judy bonds is a coal miner 's daughter .] => [<s>现在<unk><unk>是<unk><unk>。<e>]
#
# [you can 't see it , but it 's there . "] => [<s>你看不见它，但它确实存在。"<e>]
#
# [i could have started anywhere in the sentence , and i could have made this entire thing .] => [<s>我可以从任何角度来看，我可以在任何地方都能得到。<e>]
#
# [now , folks often ask us at the james randi educational foundation , they call me , they say , " why are you so concerned about this , mr. randi ] => [<s>现在，人们经常问我的英国<unk><unk>，问他们，"为什么你要把这个<unk>交给你，他们说："<e>]
#
# [so we didn 't just launch two of them like this , we launched 28 of them .] => [<s>所以我们没有<unk>这条<unk>，但他们也是<unk><unk>。<e>]
#
# [the first lesson is about that design can change not just your product .] => [<s>第一个设计是关于设计的。<e>]
# [why not  i think this is rather important .] => [<s>为什么我认为这不是很重要的。<e>]
#
# [that was all a preliminary hearing judge had to listen to , to bind mr. carrillo over to stand trial for a first-degree murder .] => [<s>这是我当时想说的所有事都是<unk><unk><unk><unk><unk>的<unk><unk><unk><unk>的<unk>。<e>]
#
# [or is it possible to find something a little bit more inspiring to work towards ] => [<s>还是会发现一些更有效的方法来帮助我们更<unk>一些东西<e>]
#
# [now these three guys up here , furchgott , ignarro and murad , won the nobel prize for medicine back in 1998 .] => [<s>现在这三个<unk>，<unk>，<unk>，<unk>，<unk>，<unk><unk><unk><unk>。<e>]
#
# [now , let 's think about this for a minute .] => [<s>现在，让我们来想一想。<e>]
#
# [so it 's got the right shape to produce the lensing .] => [<s>它已经被称为<unk><unk>的<unk>了。<e>]
#
# [in other words , the term we use in business is , we have to have strategic alignment .] => [<s>换句话说，我们的"<unk>"是的，我们必须使用<unk>。<e>]
#
# [" our conversation started with me saying , ' i 'm bored , ' and her replying , ' when i 'm bored i eat pretzels . ' i remember this distinctly because it came up a lot . "] => [<s>"我们开始的时候，我的<unk>让我想起我的<unk>，"当我<unk>时，我的<unk>却<unk>，<unk>，<unk>，我知道他们的<unk>。<e>]
#
# [you see 300 patients , 20 surgeries and 90,000 people to manage .] => [<s>你可以看到有300,000名志愿者,他们用的是<unk>.<e>]
#
# [and carrie says , " boy , i feel like i didn 't really draw out the main point on the hegelian dialectic . "] => [<s>她回答道，"我的意思是，我的<unk><unk><unk><unk>的<unk>。"<e>]
#
# [pretty soon she had 30 women in the village working for her embroidery business .] => [<s>她很快就知道了她在<unk>的<unk><unk>。<e>]
#
# [he was too busy .] => [<s>他太<unk>了。<e>]
#
# [what happens is that bacteria are able to count how many of me and how many of you .] => [<s>这些细菌有多少<unk>是我的<unk>和你有多少选择<e>]
#
# [what happens to education ] => [<s>教育会带来什么<e>]
#
# [billie jean is not my lover she 's just a girl who claims that i am the one but the kid is not my son all right .] => [<s><unk>我的不是我的儿子是个孩子，但是我不是一个<unk>的孩子，我认为她是个<unk>。<e>]
#
# [and we were like , " oh , tell us more .] => [<s>我们说："哦，也许更重要。<e>]
#
# [so , there 's a couple of things to say about tms .] => [<s>有一些关于<unk>的事情<e>]
#
# [and so , i thought , what about if we just take the rudder from the back of the boat to the front , would we have better control ] => [<s>所以我想，如果我们把<unk><unk>，我们就能不能再回到<unk>了，对吧<e>]
#
# [i mean , in many ways , the way that we 're doing it , we 're still operating in the dark .] => [<s>我的意思是，我们在很多情况下，我们在<unk>。<e>]
#
# [and then carrie reads all the books in the original greek and latin , goes to all the lectures .] => [<s>而<unk><unk>的书都出自<unk>的<unk>，写着，<e>]
#
# [i actually found three separate recipes in the literature .] => [<s>我在<unk><unk>了三个字<e>]
#
# [and it is an awesome thing to be a part of empowering someone in this way .] => [<s>这是个<unk>的<unk>的愿望<e>]
#
# [by all purposes and means , aurora 's brain has incorporated that artificial device as an extension of her body .] => [<s><unk>，所有的大脑，它是通过大脑的<unk>结构的。<e>]
#
# [that shouldn 't be news to any of us .] => [<s>但我们没有任何精神疾病<e>]
#
# [this was the estimate of the new survey .] => [<s>这是新的调查<e>]
#
# [but that 's not the really crazy change that we 're living in the middle of .] => [<s>但这并不是我们在改变生活中所扮演的角色。<e>]
#
# [people have been debating the causes of happiness for a really long time , in fact for thousands of years , but it seems like many of those debates remain unresolved .] => [<s>人们常常会争辩我们的世界，几乎所有的<unk>都是相当<unk>的，但实际上，它几乎没有被看作是非常普遍的。<e>]
#
# [thank you .] => [<s>谢谢。<e>]
#
# [and the first surgery of the day happened to be an obstetrical case .] => [<s>第一天的第一天是<unk>的一天会被<unk>。<e>]
#
# [one of many different techniques using wireless sensors .] => [<s>有很多不同的<unk>装置<e>]
#
# [and that 's over 20 hours of video every minute .] => [<s>在视频里约一分钟一分钟。<e>]
#
# [we will provide all the open source software for them , maybe starting next month .] => [<s>我们提供给所有的<unk>提供了15分钟的<unk><e>]
#
# [what does this all mean for us ] => [<s>我们对所有这些都意味着什么<e>]
#
# [and honestly , even though i love the designs that we were building , i was always frightened that i wouldn 't really love it , because i fell in love with that wildscape -- and how could you recreate that magic ] => [<s>坦白说，我觉得很奇怪，因为我爱上了我的<unk>，我们总是在<unk>，因为我爱上了你的爱，你能把它们<unk>。<e>]
#
# [so you 've got to watch your space for that .] => [<s>所以你必须去看你的<unk><e>]
#
# [would you ask me those questions ] => [<s>你问我这些问题<e>]
#
# [you open all your senses for this wonderful richness that is given to us .] => [<s>你敞开<unk>的所有你的生活都会<unk><e>]
#
# [not yours , of course -- other people 's .] => [<s>当然，你的世界，还有其他的。<e>]
#
# [so let me go on the next short video .] => [<s>让我们再来看一下一段视频。<e>]

# %%
print("Everything seems OK...")
print("Accomplished!")
# Out:
# Everything seems OK...
# Accomplished!
