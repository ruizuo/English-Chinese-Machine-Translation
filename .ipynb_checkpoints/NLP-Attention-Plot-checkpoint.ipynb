# %% [markdown]
# # Machine Translation

# %%
import re
import os
import numpy as np
import jieba
import collections

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.backend import permute_dimensions, sqrt, constant
from tensorflow import matrix_band_part

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split

# %%
# Verify  GPU
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7542818612859651377
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15862523495
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#   }
# }
# incarnation: 502220145487148205
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:87:00.0, compute capability: 6.0"
# ]

# %% [markdown]
# ## 1. Data Preparation
# ### 1.1 Load Data

# %%
# Load English data
print("Loading data...")

def load_data(path):
    """
    Load dataset
    """
    input_file = os.path.join(path)
    with open(input_file, "r") as f:
        data = f.read()

    return data.split('\n')

en_sentences = load_data('data/train.txt.en')

# Load Chinese data
cn_sentences = load_data('data/train.txt.zh')
# Out:
# Loading data...

# %%
print('Dataset Loaded')
print("lenght of Source sentences:", len(en_sentences))
print("Source sample: ", en_sentences[0])

print("lenght of Target sentences:", len(en_sentences))
print("Target sample: ", cn_sentences[0].replace(" ",""))
# Out:
# Dataset Loaded
# lenght of Source sentences: 209941
# Source sample:  This is Bill Lange . I 'm Dave Gallo .
# lenght of Target sentences: 209941
# Target sample:  大卫.盖罗：这位是比尔.兰格，我是大卫.盖罗。

# %% [markdown]
# ### 1.2 Filter out sentences with length more than 50

# %%
en_list = []
cn_list = []

#===========input parameter ========================
max_len = 50
#max_vocab_size = 50000
en_vocab_size = 50000 
cn_vocab_size = 10000
max_rows = 200000
#===================================================

def clean_eng(x):
    x = x.lower()
    x = re.sub('[!?]','',x)
    return x

def clean_chn(x):
    x = re.sub('[!?！？\n]','',x)
    x = jieba.cut(x)
    return ' '.join(x)

# %%
for i in range(len(en_sentences)):
    # Add <s> start and <e> end to the each target sentence  
    en_sentences[i] = clean_eng(en_sentences[i])
    cn_sentences[i] = "<s> " + clean_chn(cn_sentences[i].replace(" ","")) + " <e>"
    
    if len(en_sentences[i].split()) <= max_len and len(cn_sentences[i].split()) <= max_len:
        en_list.append(en_sentences[i])
        cn_list.append(cn_sentences[i])
        
print("lenght of Source:", len(en_list))
print("Source: ", en_list[0])

print("lenght of Target sentences:", len(cn_list))
print("Target: ", cn_list[0])
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.809 seconds.
# Prefix dict has been built succesfully.
# lenght of Source: 200884
# Source:  this is bill lange . i 'm dave gallo .
# lenght of Target sentences: 200884
# Target:  <s> 大卫 . 盖罗 ： 这位 是 比尔 . 兰格 ， 我 是 大卫 . 盖罗 。 <e>

# %%
for i in range(5):
    print(en_list[i])
    print(cn_list[i])
# Out:
# this is bill lange . i 'm dave gallo .
# <s> 大卫 . 盖罗 ： 这位 是 比尔 . 兰格 ， 我 是 大卫 . 盖罗 。 <e>
# and we 're going to tell you some stories from the sea here in video .
# <s> 我们 将 用 一些 影片 来 讲述 一些 深海 里 的 故事 。 <e>
# we 've got some of the most incredible video of titanic that 's ever been seen , and we 're not going to show you any of it .
# <s> 我们 这有 不少 精彩 的 泰坦尼克 的 影片 ， 可惜 您 今天 看不到 。 <e>
# the truth of the matter is that the titanic -- even though it 's breaking all sorts of box office records -- it 's not the most exciting story from the sea .
# <s> 泰坦尼克号 是 拿 了 不少 票房 冠军 但 事实上 它 并 不是 关于 海洋 的 最 刺激 的 故事 。 <e>
# and the problem , i think , is that we take the ocean for granted .
# <s> 原因 在于 我们 一直 没 把 海洋 当 回事儿 。 <e>

# %% [markdown]
# ### 1.3 Split sentence into words

# %%
en_words_counter = collections.Counter([word for sentence in en_list for word in sentence.split()])
cn_words_counter = collections.Counter([word for sentence in cn_list for word in sentence.split()])

print('{} English words.'.format(len([word for sentence in en_sentences for word in sentence.split()])))
print('{} unique English words.'.format(len(en_words_counter)))
print('20 Most common words in the English dataset:')
print('"' + '" "'.join(list(zip(*en_words_counter.most_common(20)))[0]) + '"')
print("---------------------------------------------------------------------------------------------------------------")
print('{} Chinese words.'.format(len([word for sentence in cn_sentences for word in sentence.split()])))
print('{} unique Chinese words.'.format(len(cn_words_counter)))
print('20 Most common words in the Chinese dataset:')
print('"' + '" "'.join(list(zip(*cn_words_counter.most_common(20)))[0]) + '"')
# Out:
# 4250820 English words.
# 55163 unique English words.
# 20 Most common words in the English dataset:
# "," "." "the" "and" "to" "of" "a" "that" "i" "it" "in" "you" "we" "is" "'s" "this" "so" """ "they" "was"
# ---------------------------------------------------------------------------------------------------------------
# 4180600 Chinese words.
# 82572 unique Chinese words.
# 20 Most common words in the Chinese dataset:
# "的" "<s>" "<e>" "，" "。" "我" "我们" "是" "在" "了" "你" """ "一个" "这" "有" "他们" "和" "就" "它" "这个"

# %% [markdown]
# ### 1.4 Split data into training and testing set

# %%
### Split the preccessed data into training and test sets using Sklearn ###
en_train, en_test, cn_train, cn_test = train_test_split(np.array(en_list), 
                                                        np.array(cn_list), 
                                                        test_size=0.1, 
                                                        random_state=42,
                                                        shuffle = True)

# %%
print("en_train.shape: ", en_train.shape)
print("en_test.shape: ", en_test.shape)
print("cn_train.shape: ", cn_train.shape)
print("cn_test.shape: ", cn_test.shape)
# Out:
# en_train.shape:  (180795,)
# en_test.shape:  (20089,)
# cn_train.shape:  (180795,)
# cn_test.shape:  (20089,)

# %% [markdown]
# ## 2. Tokenize and Padding

# %% [markdown]
# ### 2.1 Tokenize English and Chinese sentences

# %%
def tokenize(texts, maxlen, num_words):
    tokenizer = Tokenizer(filters='',num_words = num_words, oov_token = '<unk>')
    tokenizer.fit_on_texts(texts)
    vocab_size = len(tokenizer.index_word) + 1
    max_len = max(list(map(lambda i: len(i.split()), texts)))
    max_len =  min(max_len, maxlen)
    vocab_size = min(vocab_size, num_words)

    seqs = tokenizer.texts_to_sequences(texts)
    padded_seqs = pad_sequences(seqs, max_len, padding='post')
    return tokenizer, vocab_size, max_len, padded_seqs

# %%
# Create English tokeninzer for training set
src_tokenizer, src_vocab_size, src_max_len, en_input_seq = \
tokenize(en_train, max_len, en_vocab_size)

# %%
print("src_tokenizer.index_word: ", len(src_tokenizer.index_word))
print("src_vocab_size: ", src_vocab_size)
print("src_max_len: ", src_max_len)
print("en_input_seq.shape: ", en_input_seq.shape)
print("en_input_seq: ", en_input_seq)
# Out:
# src_tokenizer.index_word:  52939
# src_vocab_size:  50000
# src_max_len:  50
# en_input_seq.shape:  (180795, 50)
# en_input_seq:  [[   5    8  132 ...    0    0    0]
#  [  10  222   11 ...    0    0    0]
#  [ 340    2   14 ...    0    0    0]
#  ...
#  [  48 3818    9 ...    3    0    0]
#  [   5   17   15 ...    0    0    0]
#  [  26   35   20 ...    0    0    0]]

# %%
# Create Chinese tokeninzer
tar_tokenizer, tar_vocab_size, tar_max_len, de_input_seq = \
tokenize(cn_train, max_len, cn_vocab_size)

# %%
print("tar_tokenizer length: ", len(tar_tokenizer.index_word))
print("tar_tokenizer.index_word: ", tar_tokenizer.index_word[10])
print("tar_vocab_size: ", tar_vocab_size)
print("tar_max_len: ", tar_max_len)
print("de_input_seq.shape: ", de_input_seq.shape)
print("de_input_seq: ", de_input_seq)
# Out:
# tar_tokenizer length:  78590
# tar_tokenizer.index_word:  在
# tar_vocab_size:  10000
# tar_max_len:  50
# de_input_seq.shape:  (180795, 50)
# de_input_seq:  [[   3  102  878 ...    0    0    0]
#  [   3    7   10 ...    4    0    0]
#  [   3  658  133 ...    0    0    0]
#  ...
#  [   3   24  108 ... 1243    6    4]
#  [   3   15   25 ...    0    0    0]
#  [   3   40   66 ...    0    0    0]]

# %%
print(tar_tokenizer.index_word[12])
# Out:
# 你

# %%
de_target_seq = de_input_seq[:,1:]
print("de_target_seq.shape: ", de_target_seq.shape)
print("de_target_seq: ", de_target_seq)
# Out:
# de_target_seq.shape:  (180795, 49)
# de_target_seq:  [[ 102  878   22 ...    0    0    0]
#  [   7   10  212 ...    4    0    0]
#  [ 658  133   35 ...    0    0    0]
#  ...
#  [  24  108 3411 ... 1243    6    4]
#  [  15   25  277 ...    0    0    0]
#  [  40   66   68 ...    0    0    0]]

# %%
de_input_seq = de_input_seq[:,:-1]

print("de_input_seq.shape: ", de_input_seq.shape)
print("de_input_seq: ", de_input_seq)
# Out:
# de_input_seq.shape:  (180795, 49)
# de_input_seq:  [[   3  102  878 ...    0    0    0]
#  [   3    7   10 ...   13    4    0]
#  [   3  658  133 ...    0    0    0]
#  ...
#  [   3   24  108 ...  294 1243    6]
#  [   3   15   25 ...    0    0    0]
#  [   3   40   66 ...    0    0    0]]

# %%
print('max len: ' + str((src_max_len, tar_max_len)))
print('vocab size: ' + str((src_vocab_size, tar_vocab_size)))
# Out:
# max len: (50, 50)
# vocab size: (50000, 10000)

# %%
print(de_target_seq.shape)
print(tar_vocab_size)

del en_sentences
del cn_sentences
# Out:
# (180795, 49)
# 10000

# %%
de_target_matrix = to_categorical(de_target_seq, tar_vocab_size)

# %%
print(de_target_matrix.shape)
# Out:
# (180795, 49, 10000)

# %% [markdown]
# ## 3. Callback Functions

# %% [markdown]
# ### 3.1 Reduce learning rate when a metric has stopped improving
# Now, we start defining callback functions...

# %%
lr_reducer = ReduceLROnPlateau(monitor='val_loss', 
                               factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=2, 
                               min_lr=1e-6)

# %% [markdown]
# ### 3.2 Model checkpoint

# %%
save_dir = os.getcwd()
weight_path = './weight/Attention.h5'

# model.save(model_path)
print('Model Path at %s ' % weight_path)

# Save the model after every epoch if model improves
model_checkpoint = ModelCheckpoint(weight_path, 
                                   monitor="val_acc", 
                                   save_best_only=True,
                                   save_weights_only=True, 
                                   verbose=1)
# Out:
# Model Path at ./weight/Attention.h5

# %% [markdown]
# ### 3.3 Early Stop

# %%
early_stopping = EarlyStopping(monitor='val_loss', 
                               patience=4, 
                               verbose=1)

# %% [markdown]
# ### 3.4 Monitor Learning Rate for every epoch

# %%
history_lr = []  # Variable to store leraning rate history

class MonitorLR(tf.keras.callbacks.Callback):   
    def on_epoch_end(self, epoch, logs=None):
        print("\n")
        print("Learning Rate:", K.eval(self.model.optimizer.lr))
        print("\n")
        history_lr.append(K.eval(self.model.optimizer.lr))
              
monitorLR = MonitorLR()

# %% [markdown]
# ### 3.5 Callback function
# To be applied at given stages of the training procedure.

# %%
callbacks=[lr_reducer,
           monitorLR, 
           model_checkpoint,
           early_stopping]

# %% [markdown]
# ## 4. Model
# ### 4.1 Build Model

# %%
print("Now, creating model...")
#======== model paramters =======
latent_dim = 1024
#======== train paramters =======
#epochs = 100
epochs = 30
batch_size = 256
name = "Attention"
#================================
# Out:
# Now, creating model...

# %% [markdown]
# ### 4.2  Dot Product

# %%
def scaled_dot_product_attention(Q,K,V,mask = False):
    
    assert K.shape.as_list() == V.shape.as_list(), 'shape of K and V must same'
    assert Q.shape.as_list()[2] == K.shape.as_list()[2]
    k = Q.shape.as_list()[2]
    
    ## define layers
    matmul_1 = Dot(axes=-1, name = 'dot_att_matmul1')
    matmul_2 = Dot(axes= 1, name = 'dot_att_matmul2')
    scale = Lambda(lambda x: x / sqrt(constant(k)), name = 'dot_att_scale')
    softmax = Activation(activation='softmax',name = 'dot_att_softmax')
    mask_layer = Lambda(lambda x: matrix_band_part(x, -1 ,0), name = 'dot_att_mask')     # lower tri matrix
    
    y = matmul_1([K,Q])
    y = scale(y)
    y = mask_layer(y)
    y = softmax(y)
    y = matmul_2([y,V])
    return y

# %% [markdown]
# ### 4.3 Encoder Model

# %%
# encoder model
enc_input = Input((None,), name = 'encoder_input_seq')
enc_embed = Embedding(src_vocab_size + 1, latent_dim, name = 'encoder_embed')
encoder = LSTM(latent_dim, return_state=True, return_sequences=True, name = 'encoder')

enc_z, enc_state_h, enc_state_c = encoder(enc_embed(enc_input))
enc_states = [enc_state_h, enc_state_c]
enc_model = Model(enc_input, enc_states)

enc_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input_seq (InputLaye (None, None)              0
# _________________________________________________________________
# encoder_embed (Embedding)    (None, None, 1024)        51201024
# _________________________________________________________________
# encoder (LSTM)               [(None, None, 1024), (Non 8392704
# =================================================================
# Total params: 59,593,728
# Trainable params: 59,593,728
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 4.4 Decoder Model

# %%
# decoder model
dec_input = Input((None,), name = 'decoder_input_seq')
dec_state_h_input = Input((latent_dim,), name = 'decoder_input_state_h')
dec_state_c_input = Input((latent_dim,), name = 'decoder_input_state_c')
dec_states_input = [dec_state_h_input, dec_state_c_input]

enc_z_input = Input((None, latent_dim))

dec_embed = Embedding(tar_vocab_size + 1, latent_dim, name = 'decoder_embed')
decoder = LSTM(latent_dim, return_state=True, return_sequences=True, name = 'decoder')
dec_fc = TimeDistributed(Dense(tar_vocab_size, activation='softmax'), name = 'decoder_output')

dec_z, dec_state_h, dec_state_c = decoder(dec_embed(dec_input), initial_state = dec_states_input)
dec_states_output = [dec_state_h, dec_state_c]
dec_z = scaled_dot_product_attention(dec_z, enc_z_input, enc_z_input, mask = True)
dec_output = dec_fc(dec_z)

dec_model = Model([enc_z_input, dec_input]+dec_states_input, [dec_output]+dec_states_output)

dec_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# decoder_input_seq (InputLayer)  (None, None)         0
# __________________________________________________________________________________________________
# decoder_embed (Embedding)       (None, None, 1024)   10241024    decoder_input_seq[0][0]
# __________________________________________________________________________________________________
# decoder_input_state_h (InputLay (None, 1024)         0
# __________________________________________________________________________________________________
# decoder_input_state_c (InputLay (None, 1024)         0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            (None, None, 1024)   0
# __________________________________________________________________________________________________
# decoder (LSTM)                  [(None, None, 1024), 8392704     decoder_embed[0][0]
#                                                                  decoder_input_state_h[0][0]
#                                                                  decoder_input_state_c[0][0]
# __________________________________________________________________________________________________
# dot_att_matmul1 (Dot)           (None, None, None)   0           input_1[0][0]
#                                                                  decoder[0][0]
# __________________________________________________________________________________________________
# dot_att_scale (Lambda)          (None, None, None)   0           dot_att_matmul1[0][0]
# __________________________________________________________________________________________________
# dot_att_mask (Lambda)           (None, None, None)   0           dot_att_scale[0][0]
# __________________________________________________________________________________________________
# dot_att_softmax (Activation)    (None, None, None)   0           dot_att_mask[0][0]
# __________________________________________________________________________________________________
# dot_att_matmul2 (Dot)           (None, None, 1024)   0           dot_att_softmax[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# decoder_output (TimeDistributed (None, None, 10000)  10250000    dot_att_matmul2[0][0]
# ==================================================================================================
# Total params: 28,883,728
# Trainable params: 28,883,728
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### 4.5 Encoder_Decoder

# %%
# encoder_decoder training model
tar_logit, _, _ = decoder(dec_embed(dec_input), initial_state= enc_states)
tar_logit = scaled_dot_product_attention(tar_logit, enc_z, enc_z)

tar_output = dec_fc(tar_logit)

enc_dec_model = Model([enc_input, dec_input], tar_output)
enc_dec_model.compile(optimizer='adam', loss='categorical_crossentropy')

enc_dec_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input_seq (InputLayer)  (None, None)         0
# __________________________________________________________________________________________________
# encoder_embed (Embedding)       (None, None, 1024)   51201024    encoder_input_seq[0][0]
# __________________________________________________________________________________________________
# decoder_input_seq (InputLayer)  (None, None)         0
# __________________________________________________________________________________________________
# encoder (LSTM)                  [(None, None, 1024), 8392704     encoder_embed[0][0]
# __________________________________________________________________________________________________
# decoder_embed (Embedding)       (None, None, 1024)   10241024    decoder_input_seq[0][0]
# __________________________________________________________________________________________________
# decoder (LSTM)                  [(None, None, 1024), 8392704     decoder_embed[1][0]
#                                                                  encoder[0][1]
#                                                                  encoder[0][2]
# __________________________________________________________________________________________________
# dot_att_matmul1 (Dot)           (None, None, None)   0           encoder[0][0]
#                                                                  decoder[1][0]
# __________________________________________________________________________________________________
# dot_att_scale (Lambda)          (None, None, None)   0           dot_att_matmul1[0][0]
# __________________________________________________________________________________________________
# dot_att_mask (Lambda)           (None, None, None)   0           dot_att_scale[0][0]
# __________________________________________________________________________________________________
# dot_att_softmax (Activation)    (None, None, None)   0           dot_att_mask[0][0]
# __________________________________________________________________________________________________
# dot_att_matmul2 (Dot)           (None, None, 1024)   0           dot_att_softmax[0][0]
#                                                                  encoder[0][0]
# __________________________________________________________________________________________________
# decoder_output (TimeDistributed (None, None, 10000)  10250000    dot_att_matmul2[0][0]
# ==================================================================================================
# Total params: 88,477,456
# Trainable params: 88,477,456
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### 4.6 Model Structure

# %%
if not os.path.exists('./weight/'):
    os.mkdir('./weight/')


try:
    enc_dec_model.load_weights(weight_path)
    print('load from previous model')
except:
    print('train a new model')
    
optimizer = tf.keras.optimizers.Adam(lr = 0.001,
                                     beta_1=0.9, 
                                     beta_2=0.999, 
                                     amsgrad=False)

enc_dec_model.compile(loss = 'categorical_crossentropy',
                      optimizer= optimizer,
                      metrics=['accuracy'])    
    
# Save model as image
plot_model(enc_dec_model, 
           "./images/" + name + ".png", 
           show_shapes=True, 
           show_layer_names=True)

#  model summary
enc_dec_model.summary()

print("Done!")
# Out:
# train a new model
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input_seq (InputLayer)  (None, None)         0
# __________________________________________________________________________________________________
# encoder_embed (Embedding)       (None, None, 1024)   51201024    encoder_input_seq[0][0]
# __________________________________________________________________________________________________
# decoder_input_seq (InputLayer)  (None, None)         0
# __________________________________________________________________________________________________
# encoder (LSTM)                  [(None, None, 1024), 8392704     encoder_embed[0][0]
# __________________________________________________________________________________________________
# decoder_embed (Embedding)       (None, None, 1024)   10241024    decoder_input_seq[0][0]
# __________________________________________________________________________________________________
# decoder (LSTM)                  [(None, None, 1024), 8392704     decoder_embed[1][0]
#                                                                  encoder[0][1]
#                                                                  encoder[0][2]
# __________________________________________________________________________________________________
# dot_att_matmul1 (Dot)           (None, None, None)   0           encoder[0][0]
#                                                                  decoder[1][0]
# __________________________________________________________________________________________________
# dot_att_scale (Lambda)          (None, None, None)   0           dot_att_matmul1[0][0]
# __________________________________________________________________________________________________
# dot_att_mask (Lambda)           (None, None, None)   0           dot_att_scale[0][0]
# __________________________________________________________________________________________________
# dot_att_softmax (Activation)    (None, None, None)   0           dot_att_mask[0][0]
# __________________________________________________________________________________________________
# dot_att_matmul2 (Dot)           (None, None, 1024)   0           dot_att_softmax[0][0]
#                                                                  encoder[0][0]
# __________________________________________________________________________________________________
# decoder_output (TimeDistributed (None, None, 10000)  10250000    dot_att_matmul2[0][0]
# ==================================================================================================
# Total params: 88,477,456
# Trainable params: 88,477,456
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Done!

# %%
# %pylab inline
import matplotlib.image as mpimg
img=mpimg.imread("./images/" + name + ".png")

plt.figure(figsize = (20,15))
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /root/miniconda3/envs/new/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['multiply', 'sqrt', 'concatenate', 'add', 'maximum', 'minimum', 'average', 'dot', 'subtract']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ### 4.7 Fit Model

# %%
history = enc_dec_model.fit([en_input_seq, de_input_seq], 
                            de_target_matrix,
                            batch_size=batch_size,
                            epochs=epochs, 
                            shuffle = True,
                            callbacks = callbacks,
                            validation_split = 0.1)
# Out:
# /root/miniconda3/envs/new/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 162715 samples, validate on 18080 samples
# Epoch 1/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 2.3029 - acc: 0.6678
#
# Learning Rate: 0.001
#
#
#
# Epoch 00001: val_acc improved from -inf to 0.71323, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 826s 5ms/step - loss: 2.3026 - acc: 0.6679 - val_loss: 1.9457 - val_acc: 0.7132
# Epoch 2/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.7876 - acc: 0.7349
#
# Learning Rate: 0.001
#
#
#
# Epoch 00002: val_acc improved from 0.71323 to 0.75028, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 717s 4ms/step - loss: 1.7875 - acc: 0.7349 - val_loss: 1.6421 - val_acc: 0.7503
# Epoch 3/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.5121 - acc: 0.7623
#
# Learning Rate: 0.001
#
#
#
# Epoch 00003: val_acc improved from 0.75028 to 0.76960, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 713s 4ms/step - loss: 1.5120 - acc: 0.7623 - val_loss: 1.4362 - val_acc: 0.7696
# Epoch 4/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.3325 - acc: 0.7788
#
# Learning Rate: 0.001
#
#
#
# Epoch 00004: val_acc improved from 0.76960 to 0.77985, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 716s 4ms/step - loss: 1.3324 - acc: 0.7788 - val_loss: 1.3298 - val_acc: 0.7798
# Epoch 5/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.2397 - acc: 0.7873
#
# Learning Rate: 0.001
#
#
#
# Epoch 00005: val_acc improved from 0.77985 to 0.78344, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 712s 4ms/step - loss: 1.2396 - acc: 0.7874 - val_loss: 1.2856 - val_acc: 0.7834
# Epoch 6/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.2320 - acc: 0.7874
#
# Learning Rate: 0.001
#
#
#
# Epoch 00006: val_acc did not improve from 0.78344
# 162715/162715 [==============================] - 712s 4ms/step - loss: 1.2320 - acc: 0.7874 - val_loss: 1.3125 - val_acc: 0.7813
# Epoch 7/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.2118 - acc: 0.7891
#
# Learning Rate: 0.001
#
#
#
# Epoch 00007: val_acc improved from 0.78344 to 0.78819, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 715s 4ms/step - loss: 1.2118 - acc: 0.7891 - val_loss: 1.2492 - val_acc: 0.7882
# Epoch 8/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.1976 - acc: 0.7927
#
# Learning Rate: 0.001
#
#
#
# Epoch 00008: val_acc did not improve from 0.78819
# 162715/162715 [==============================] - 712s 4ms/step - loss: 1.1977 - acc: 0.7927 - val_loss: 1.3582 - val_acc: 0.7743
# Epoch 9/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.1523 - acc: 0.7953
#
# Learning Rate: 0.001
#
#
#
# Epoch 00009: val_acc improved from 0.78819 to 0.79149, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 717s 4ms/step - loss: 1.1523 - acc: 0.7953 - val_loss: 1.2187 - val_acc: 0.7915
# Epoch 10/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.0753 - acc: 0.8050
#
# Learning Rate: 0.001
#
#
#
# Epoch 00010: val_acc improved from 0.79149 to 0.79497, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 719s 4ms/step - loss: 1.0754 - acc: 0.8050 - val_loss: 1.2011 - val_acc: 0.7950
# Epoch 11/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.0803 - acc: 0.8051
#
# Learning Rate: 0.001
#
#
#
# Epoch 00011: val_acc improved from 0.79497 to 0.79522, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 719s 4ms/step - loss: 1.0802 - acc: 0.8051 - val_loss: 1.1964 - val_acc: 0.7952
# Epoch 12/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 1.0703 - acc: 0.8065
#
# Learning Rate: 0.001
#
#
#
# Epoch 00012: val_acc did not improve from 0.79522
# 162715/162715 [==============================] - 715s 4ms/step - loss: 1.0703 - acc: 0.8065 - val_loss: 1.1985 - val_acc: 0.7946
# Epoch 13/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.9994 - acc: 0.8153
#
# Learning Rate: 0.001
#
#
#
# Epoch 00013: val_acc improved from 0.79522 to 0.80355, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 714s 4ms/step - loss: 0.9994 - acc: 0.8153 - val_loss: 1.1323 - val_acc: 0.8035
# Epoch 14/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.9578 - acc: 0.8207
#
# Learning Rate: 0.001
#
#
#
# Epoch 00014: val_acc improved from 0.80355 to 0.80686, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 714s 4ms/step - loss: 0.9579 - acc: 0.8207 - val_loss: 1.1097 - val_acc: 0.8069
# Epoch 15/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.9448 - acc: 0.8227
#
# Learning Rate: 0.001
#
#
#
# Epoch 00015: val_acc improved from 0.80686 to 0.80757, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 716s 4ms/step - loss: 0.9450 - acc: 0.8227 - val_loss: 1.1073 - val_acc: 0.8076
# Epoch 16/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.9391 - acc: 0.8233
#
# Learning Rate: 0.001
#
#
#
# Epoch 00016: val_acc improved from 0.80757 to 0.80893, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 718s 4ms/step - loss: 0.9391 - acc: 0.8233 - val_loss: 1.0987 - val_acc: 0.8089
# Epoch 17/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.9332 - acc: 0.8245
#
# Learning Rate: 0.001
#
#
#
# Epoch 00017: val_acc did not improve from 0.80893
# 162715/162715 [==============================] - 716s 4ms/step - loss: 0.9332 - acc: 0.8245 - val_loss: 1.1590 - val_acc: 0.8011
# Epoch 18/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.9333 - acc: 0.8236
#
# Learning Rate: 0.001
#
#
#
# Epoch 00018: val_acc improved from 0.80893 to 0.80971, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 714s 4ms/step - loss: 0.9332 - acc: 0.8236 - val_loss: 1.0952 - val_acc: 0.8097
# Epoch 19/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.9333 - acc: 0.8243
#
# Learning Rate: 0.001
#
#
#
# Epoch 00019: val_acc did not improve from 0.80971
# 162715/162715 [==============================] - 714s 4ms/step - loss: 0.9333 - acc: 0.8243 - val_loss: 1.1378 - val_acc: 0.8043
# Epoch 20/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.9241 - acc: 0.8253
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00020: val_acc did not improve from 0.80971
# 162715/162715 [==============================] - 716s 4ms/step - loss: 0.9241 - acc: 0.8253 - val_loss: 1.1014 - val_acc: 0.8090
# Epoch 21/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.8279 - acc: 0.8393
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00021: val_acc improved from 0.80971 to 0.81325, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 709s 4ms/step - loss: 0.8279 - acc: 0.8393 - val_loss: 1.0682 - val_acc: 0.8132
# Epoch 22/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.8126 - acc: 0.8418
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00022: val_acc did not improve from 0.81325
# 162715/162715 [==============================] - 712s 4ms/step - loss: 0.8128 - acc: 0.8418 - val_loss: 1.0848 - val_acc: 0.8122
# Epoch 23/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.8131 - acc: 0.8418
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00023: val_acc improved from 0.81325 to 0.81568, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 713s 4ms/step - loss: 0.8130 - acc: 0.8418 - val_loss: 1.0606 - val_acc: 0.8157
# Epoch 24/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.7808 - acc: 0.8469
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00024: val_acc improved from 0.81568 to 0.81663, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 716s 4ms/step - loss: 0.7808 - acc: 0.8469 - val_loss: 1.0490 - val_acc: 0.8166
# Epoch 25/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.7611 - acc: 0.8503
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00025: val_acc improved from 0.81663 to 0.81730, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 717s 4ms/step - loss: 0.7611 - acc: 0.8503 - val_loss: 1.0473 - val_acc: 0.8173
# Epoch 26/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.7478 - acc: 0.8524
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00026: val_acc improved from 0.81730 to 0.81754, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 719s 4ms/step - loss: 0.7477 - acc: 0.8524 - val_loss: 1.0467 - val_acc: 0.8175
# Epoch 27/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.7368 - acc: 0.8538
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00027: val_acc improved from 0.81754 to 0.81902, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 714s 4ms/step - loss: 0.7369 - acc: 0.8538 - val_loss: 1.0369 - val_acc: 0.8190
# Epoch 28/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.7185 - acc: 0.8571
#
# Learning Rate: 0.0003162278
#
#
#
# Epoch 00028: val_acc improved from 0.81902 to 0.81903, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 715s 4ms/step - loss: 0.7185 - acc: 0.8571 - val_loss: 1.0376 - val_acc: 0.8190
# Epoch 29/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.7266 - acc: 0.8563
#
# Learning Rate: 0.000100000005
#
#
#
# Epoch 00029: val_acc did not improve from 0.81903
# 162715/162715 [==============================] - 716s 4ms/step - loss: 0.7267 - acc: 0.8563 - val_loss: 1.0412 - val_acc: 0.8189
# Epoch 30/30
# 162560/162715 [============================>.] - ETA: 0s - loss: 0.6791 - acc: 0.8645
#
# Learning Rate: 0.000100000005
#
#
#
# Epoch 00030: val_acc improved from 0.81903 to 0.82032, saving model to ./weight/Attention.h5
# 162715/162715 [==============================] - 717s 4ms/step - loss: 0.6790 - acc: 0.8645 - val_loss: 1.0333 - val_acc: 0.8203

# %% [markdown]
# ## 5. Evaluate Model
# ### 5.1 Load Weight

# %%
print("Now, we start evaluating the model...")
# Load weight
print(weight_path)
enc_dec_model.load_weights(weight_path)
print("Weights were loaded!")
# Out:
# Now, we start evaluating the model...
# ./weight/Attention.h5
# Weights were loaded!

# %% [markdown]
# ### 5.2 Score training set

# %%
scores_train = enc_dec_model.evaluate([en_input_seq, de_input_seq], 
                                       de_target_matrix,
                                       verbose=1)

print('Train loss:', scores_train[0])
print('Train accuracy:', scores_train[1])
# Out:
# 180795/180795 [==============================] - 860s 5ms/step
# Train loss: 0.7022000737328581
# Train accuracy: 0.8623141218433107

# %% [markdown]
# ### 5.3 Score test data

# %%
# Tokenize and pad testing set
en_seqs = src_tokenizer.texts_to_sequences(en_test)
en_input_seq_test = pad_sequences(en_seqs, src_max_len, padding='post')

cn_seqs = tar_tokenizer.texts_to_sequences(cn_test)
de_input_seq_test = pad_sequences(cn_seqs, tar_max_len, padding='post')

de_target_seq_test = de_input_seq_test[:,1:]
de_input_seq_test = de_input_seq_test[:,:-1]

de_target_matrix_test = to_categorical(de_target_seq_test, tar_vocab_size)

# %%
print('en_input_seq_test.shape:', en_input_seq_test.shape)
print('de_input_seq_test.shape:', de_input_seq_test.shape)
print('de_target_seq_test.shape:', de_target_seq_test.shape)
# Out:
# en_input_seq_test.shape: (20089, 50)
# de_input_seq_test.shape: (20089, 49)
# de_target_seq_test.shape: (20089, 49)

# %%
scores_test = enc_dec_model.evaluate([en_input_seq_test, de_input_seq_test], 
                                     de_target_matrix_test,
                                     verbose=1)

print('Test loss:', scores_test[0])
print('Test accuracy:', scores_test[1])
# Out:
# 20089/20089 [==============================] - 107s 5ms/step
# Test loss: 1.0098929168947886
# Test accuracy: 0.8233666297266592

# %% [markdown]
# ### 5.4 Accuracy and Loss Trend

# %%
print("Now, we start drawing the loss and acc trends graph...")  
    
# Summarize history for accuracy 
fig = plt.figure(figsize=(10,5))
plt.plot(history.history["acc"])  
plt.plot(history.history["val_acc"])  
plt.title("Accuracy")  
plt.ylabel("accuracy")  
plt.xlabel("epoch")  
plt.legend(["train","eva"],loc="upper left")  
plt.show()
    
# Summarize history for loss
fig = plt.figure(figsize=(10,5))     
plt.plot(history.history["loss"])  
plt.plot(history.history["val_loss"])  
plt.title("Loss")  
plt.ylabel("loss")  
plt.xlabel("epoch")  
plt.legend(["train","eva"],loc="upper left")  
plt.show()
# Out:
# Now, we start drawing the loss and acc trends graph...

# %% [markdown]
# ### 5.5 Learning Rate

# %%
#summarize history for Learning rate
fig = plt.figure(figsize=(10,5))     
plt.plot(history_lr, label="lr")
plt.title("Learning Rate")  
plt.ylabel("Learning Rate")  
plt.xlabel("epoch")  
plt.legend()  
plt.show()

# %% [markdown]
# ## 6. Translate Samples

# %%
import pandas as pd
df = pd.read_csv('./data/cmn.txt',sep='\t', header=None, names = ['en','cn'])
df.head()
# Out:
#        en     cn
# 0     Hi.     嗨。
# 1     Hi.    你好。
# 2    Run.  你用跑的。
# 3   Wait!    等等！
# 4  Hello!    你好。

# %%
for i in range(99, 100):
    #src_raw = en_test[i]
    src_raw = df.en.values[i]
    src = clean_eng(src_raw)
    print("src:", src)
    #src = "And we really have this incredibly simplistic view of why people work and what the labor market looks like."
    
    src_sentence = src
    tokenizers = (src_tokenizer, tar_tokenizer)
    max_len = (50,49)

    src_max_len, tar_max_len = max_len
    # initialize with encoder states

    src_tokenizer, tar_tokenizer = tokenizers
    src_index_word = src_tokenizer.index_word
    src_word_index = src_tokenizer.word_index 
    tar_index_word = tar_tokenizer.index_word
    tar_word_index = tar_tokenizer.word_index
    
    tar_token = '<s>'
    tar_index = tar_word_index.get(tar_token, None)
    if tar_index == None:
        print('start token <s> not found!')
    src_input_seq = src_tokenizer.texts_to_sequences([src_sentence])
    src_input_seq = pad_sequences(src_input_seq, maxlen=src_max_len, padding='post')
    
    print("src_input_seq: ", src_input_seq)
    
    states = enc_model.predict(src_input_seq)
    print("states: ", states)
    #print("states.shape: ", states.shape)
    
    tr, ss = ([tar_index], [tar_token], [1.0]), states  
    
    print("tr:", tr)
    print("ss: ", ss)
    
    for i in range(tar_max_len):
        # update the triple and states

        #print("Function _update_states")
        src_tokenizer, tar_tokenizer = tokenizers
        src_index_word = src_tokenizer.index_word
        src_word_index = src_tokenizer.word_index 
        tar_index_word = tar_tokenizer.index_word
        tar_word_index = tar_tokenizer.word_index
        tar_index, tar_token, tar_prob = tr
        # predict the token probability, and states

        #print("src_tokenizer: ", src_tokenizer)
        #print("=================================")
        #print("tar_tokenizer: ", tar_tokenizer)
        #print("=================================")
        #print("src_word_index: ", src_word_index)
        #print("=================================")
        #print("tar_index_word: ", tar_index_word)
        #print("=================================")
        #print("tar_word_index: ", tar_word_index)
        #print("=================================")
        
        probs, state_h, state_c = dec_model.predict([[tar_index[-1]]] + ss)
        ss_new = [state_h, state_c]
        # update the triple
        # greedy search: each time find the most likely token (last position in the sequence)
        probs = probs[0,-1,:]
        tar_index_new = np.argmax(probs)
        tar_token_new = tar_index_word.get(tar_index_new, None)
        tar_prob_new = probs[tar_index_new]
        tr_new = ( 
            tar_index + [tar_index_new],
            tar_token + [tar_token_new],
            tar_prob + [tar_prob_new]
            )   

        tr, ss = tr_new, ss_new  
        
        
        if tr[1][-1] == '<e>' or tr[1][-1] == None:
            break
            
    dec = ''.join(tr[1])    
    
    print('[%s] => [%s]'%(src,dec))

# %%
print("Everything seems OK...")
print("Accomplished!")
